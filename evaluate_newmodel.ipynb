# %%
import torch
import json
import pandas as pd
import numpy as np
from datasets import load_dataset
from FlagEmbedding import BGEM3FlagModel
from FlagEmbedding import AbsEmbedder
from transformers import AutoModel

# %% [markdown]
# ### 01 模型结构的修改的对比

# %%
### 训练后的模型的path
path_bef="./huggingface/hub/models--BAAI--bge-m3/snapshots/5617a9f61b028005a4858fdac845db406aefb181"
path_end="./model/BGEm3_Law_new/"

model_bef = AutoModel.from_pretrained(path_bef)
print(sum(param.numel() for name,param in model_bef.named_parameters()))

model_end = AutoModel.from_pretrained(path_end)
print(sum(param.numel() for name,param in model_end.named_parameters()))


# 检查两个模型是否真的是不同的实例
print(f"模型相同: {model_bef is model_end}")

# 检查模型参数是否相同
for (name1, param1), (name2, param2) in zip(model_bef.named_parameters(), model_end.named_parameters()):
    print(f"模型名称：{name1,name2}")
    print(f"参数的值：{param1,param2}")
    ## 判断参数数目是否一致：
    if torch.allclose(param1,param2):
        # 使用默认的绝对误差容限（atol）和相对误差容限（rtol）
        print("参数的值一致")
    else:
        print("参数的值不同")
# Out:
# 567754752
# 567754752
# 模型相同: False
# 模型名称：('embeddings.word_embeddings.weight', 'embeddings.word_embeddings.weight')
# 参数的值：(Parameter containing:
# tensor([[-0.0757, -0.0167, -0.0790,  ...,  0.0348,  0.0125, -0.0478],
#         [-0.0029,  0.0035,  0.0062,  ..., -0.0028,  0.0084, -0.0044],
#         [-0.0415,  0.0035, -0.0773,  ...,  0.0975,  0.1038,  0.1824],
#         ...,
#         [ 0.1523,  0.2382,  0.2328,  ...,  0.0466,  0.1892, -0.1609],
#         [ 0.0424, -0.0289, -0.1057,  ...,  0.0868,  0.1027,  0.0886],
#         [ 0.0360,  0.0206, -0.0455,  ...,  0.0236,  0.0833,  0.0753]],
#        requires_grad=True), Parameter containing:
# tensor([[-0.0757, -0.0167, -0.0790,  ...,  0.0348,  0.0125, -0.0478],
#         [-0.0029,  0.0035,  0.0062,  ..., -0.0028,  0.0084, -0.0044],
#         [-0.0415,  0.0035, -0.0773,  ...,  0.0975,  0.1038,  0.1824],
#         ...,
#         [ 0.1523,  0.2382,  0.2328,  ...,  0.0466,  0.1892, -0.1609],
#         [ 0.0424, -0.0289, -0.1057,  ...,  0.0868,  0.1027,  0.0886],
#         [ 0.0360,  0.0206, -0.0455,  ...,  0.0236,  0.0833,  0.0753]],
#        requires_grad=True))
# 参数的值一致
# 模型名称：('embeddings.position_embeddings.weight', 'embeddings.position_embeddings.weight')
# 参数的值：(Parameter containing:
# tensor([[-0.0004,  0.0107,  0.0032,  ...,  0.0048, -0.0412,  0.0006],
#         [ 0.0000, -0.0000, -0.0000,  ..., -0.0000,  0.0000, -0.0000],
#         [ 0.0384,  0.0244, -0.0635,  ..., -0.1158, -0.2249, -0.2084],
#         ...,
#         [-0.0551,  0.0567,  0.0690,  ..., -0.0244, -0.1946, -0.1621],
#         [-0.0397,  0.0875,  0.0532,  ..., -0.0830, -0.2031, -0.1378],
#         [-0.0226,  0.0276,  0.0087,  ..., -0.0103, -0.2069, -0.1896]],
#        requires_grad=True), Parameter containing:
# tensor([[-0.0004,  0.0107,  0.0032,  ...,  0.0048, -0.0412,  0.0006],
#         [ 0.0000, -0.0000, -0.0000,  ..., -0.0000,  0.0000, -0.0000],
#         [ 0.0384,  0.0244, -0.0635,  ..., -0.1158, -0.2249, -0.2084],
#         ...,
#         [-0.0551,  0.0567,  0.0690,  ..., -0.0244, -0.1946, -0.1621],
#         [-0.0397,  0.0875,  0.0532,  ..., -0.0830, -0.2031, -0.1378],
#         [-0.0226,  0.0276,  0.0087,  ..., -0.0103, -0.2069, -0.1896]],
#        requires_grad=True))
# 参数的值一致
# 模型名称：('embeddings.token_type_embeddings.weight', 'embeddings.token_type_embeddings.weight')
# 参数的值：(Parameter containing:
# tensor([[ 0.0052,  0.0203,  0.0157,  ..., -0.0054, -0.0068, -0.0063]],
#        requires_grad=True), Parameter containing:
# tensor([[ 0.0052,  0.0203,  0.0157,  ..., -0.0054, -0.0068, -0.0063]],
#        requires_grad=True))
# 参数的值一致
# 模型名称：('embeddings.LayerNorm.weight', 'embeddings.LayerNorm.weight')
# 参数的值：(Parameter containing:
# tensor([0.8843, 0.8906, 0.8564,  ..., 0.8745, 0.8652, 0.8716],
#        requires_grad=True), Parameter containing:
# tensor([0.8843, 0.8906, 0.8564,  ..., 0.8745, 0.8652, 0.8716],
#        requires_grad=True))
# 参数的值一致
# 模型名称：('embeddings.LayerNorm.bias', 'embeddings.LayerNorm.bias')
# 参数的值：(Parameter containing:
# tensor([-0.1509, -0.2415,  0.2583,  ..., -0.1512,  0.3064,  0.2825],
#        requires_grad=True), Parameter containing:
# tensor([-0.1509, -0.2415,  0.2583,  ..., -0.1512,  0.3064,  0.2825],
#        requires_grad=True))
# 参数的值一致
# 模型名称：('encoder.layer.0.attention.self.query.weight', 'encoder.layer.0.attention.self.query.weight')
# 参数的值：(Parameter containing:
# tensor([[-0.0042, -0.0191, -0.0126,  ..., -0.0341, -0.0334,  0.0007],
#         [-0.0123, -0.0386, -0.0299,  ..., -0.0555, -0.0152, -0.0083],
#         [ 0.0020, -0.0019, -0.0042,  ..., -0.0105, -0.0030, -0.0048],
#         ...,
#         [ 0.0240, -0.0157, -0.0091,  ...,  0.0425,  0.0133, -0.0053],
#         [ 0.0188,  0.0087,  0.0248,  ...,  0.0136,  0.0104, -0.0366],
#         [ 0.0278, -0.0151,  0.0060,  ...,  0.0012, -0.0061,  0.0453]],
#        requires_grad=True), Parameter containing:
# tensor([[-0.0042, -0.0191, -0.0126,  ..., -0.0341, -0.0334,  0.0007],
#         [-0.0123, -0.0386, -0.0299,  ..., -0.0555, -0.0152, -0.0083],
#         [ 0.0020, -0.0019, -0.0042,  ..., -0.0105, -0.0030, -0.0048],
#         ...,
#         [ 0.0240, -0.0157, -0.0091,  ...,  0.0425,  0.0133, -0.0053],
#         [ 0.0188,  0.0087,  0.0248,  ...,  0.0136,  0.0104, -0.0366],
#         [ 0.0278, -0.0151,  0.0060,  ...,  0.0012, -0.0061,  0.0453]],
#        requires_grad=True))
# 参数的值一致
# 模型名称：('encoder.layer.0.attention.self.query.bias', 'encoder.layer.0.attention.self.query.bias')
# 参数的值：(Parameter containing:
# tensor([-0.4961, -0.1990, -0.4309,  ..., -0.4514,  0.4783, -0.1594],
#        requires_grad=True), Parameter containing:
# tensor([-0.4961, -0.1990, -0.4309,  ..., -0.4514,  0.4783, -0.1594],
#        requires_grad=True))
# 参数的值一致
# 模型名称：('encoder.layer.0.attention.self.key.weight', 'encoder.layer.0.attention.self.key.weight')
# 参数的值：(Parameter containing:
# tensor([[-0.0027,  0.0131, -0.0078,  ..., -0.0235, -0.0182,  0.0415],
#         [ 0.0328, -0.0298,  0.0307,  ...,  0.0205,  0.0312,  0.0232],
#         [ 0.0212,  0.0318, -0.0015,  ..., -0.0146,  0.0099,  0.0162],
#         ...,
#         [ 0.0147, -0.0110, -0.0031,  ...,  0.0233, -0.0098, -0.0244],
#         [ 0.0010, -0.0040,  0.0235,  ..., -0.0190,  0.0053, -0.0160],
#         [ 0.0249, -0.0260, -0.0057,  ..., -0.0256, -0.0377,  0.0362]],
#        requires_grad=True), Parameter containing:
# tensor([[-0.0027,  0.0131, -0.0078,  ..., -0.0235, -0.0182,  0.0415],
#         [ 0.0328, -0.0298,  0.0307,  ...,  0.0205,  0.0312,  0.0232],
#         [ 0.0212,  0.0318, -0.0015,  ..., -0.0146,  0.0099,  0.0162],
#         ...,
#         [ 0.0147, -0.0110, -0.0031,  ...,  0.0233, -0.0098, -0.0244],
#         [ 0.0010, -0.0040,  0.0235,  ..., -0.0190,  0.0053, -0.0160],
#         [ 0.0249, -0.0260, -0.0057,  ..., -0.0256, -0.0377,  0.0362]],
#        requires_grad=True))
# 参数的值一致
# 模型名称：('encoder.layer.0.attention.self.key.bias', 'encoder.layer.0.attention.self.key.bias')
# 参数的值：(Parameter containing:
# tensor([-0.0299,  0.1841,  0.0025,  ..., -0.0966,  0.0147, -0.1492],
#        requires_grad=True), Parameter containing:
# tensor([-0.0299,  0.1841,  0.0025,  ..., -0.0966,  0.0147, -0.1492],
#        requires_grad=True))
# 参数的值一致
# 模型名称：('encoder.layer.0.attention.self.value.weight', 'encoder.layer.0.attention.self.value.weight')
# 参数的值：(Parameter containing:
# tensor([[ 8.8348e-03,  1.4160e-02,  2.7054e-02,  ..., -3.7720e-02,
#          -1.1269e-02,  1.4984e-02],
#         [ 6.9160e-03,  1.9165e-02,  8.7280e-03,  ..., -4.9927e-02,
#          -5.7526e-03, -1.4435e-02],
#         [-4.8401e-02, -2.7370e-03, -1.0849e-02,  ..., -2.8000e-02,
#          -4.1901e-02, -1.5526e-02],
#         ...,
#         [-3.3447e-02, -3.7140e-02, -3.2471e-02,  ..., -7.1899e-02,
#           2.8122e-02, -2.6367e-02],
#         [ 9.3520e-05, -1.5015e-02, -1.6373e-02,  ..., -2.2781e-02,
#          -4.2694e-02, -1.9547e-02],
#         [-5.4230e-02,  8.0505e-02, -5.4382e-02,  ..., -4.3030e-02,
#           2.1992e-03, -2.1011e-02]], requires_grad=True), Parameter containing:
# tensor([[ 8.8348e-03,  1.4160e-02,  2.7054e-02,  ..., -3.7720e-02,
#          -1.1269e-02,  1.4984e-02],
#         [ 6.9160e-03,  1.9165e-02,  8.7280e-03,  ..., -4.9927e-02,
#          -5.7526e-03, -1.4435e-02],
#         [-4.8401e-02, -2.7370e-03, -1.0849e-02,  ..., -2.8000e-02,
#          -4.1901e-02, -1.5526e-02],
#         ...,
#         [-3.3447e-02, -3.7140e-02, -3.2471e-02,  ..., -7.1899e-02,
#           2.8122e-02, -2.6367e-02],
#         [ 9.3520e-05, -1.5015e-02, -1.6373e-02,  ..., -2.2781e-02,
#          -4.2694e-02, -1.9547e-02],
#         [-5.4230e-02,  8.0505e-02, -5.4382e-02,  ..., -4.3030e-02,
#           2.1992e-03, -2.1011e-02]], requires_grad=True))
# 参数的值一致
# 模型名称：('encoder.layer.0.attention.self.value.bias', 'encoder.layer.0.attention.self.value.bias')
# 参数的值：(Parameter containing:
# tensor([-0.0658, -0.0595,  0.0942,  ...,  0.0005, -0.0106,  0.0039],
#        requires_grad=True), Parameter containing:
# tensor([-0.0658, -0.0595,  0.0942,  ...,  0.0005, -0.0106,  0.0039],
#        requires_grad=True))
# 参数的值一致
# 模型名称：('encoder.layer.0.attention.output.dense.weight', 'encoder.layer.0.attention.output.dense.weight')
# 参数的值：(Parameter containing:
# tensor([[ 3.7251e-03, -8.2397e-03, -6.3477e-02,  ..., -1.9409e-02,
#          -6.2084e-04, -4.4769e-02],
#         [-2.9190e-02, -1.4629e-03, -2.0248e-02,  ...,  3.2539e-03,
#           1.3359e-02,  3.3203e-02],
#         [-9.8050e-05, -3.0594e-02, -1.0468e-02,  ..., -1.5900e-02,
#          -1.6525e-02, -2.8687e-02],
#         ...,
#         [-1.1429e-02,  5.1918e-03, -4.0970e-03,  ..., -2.9016e-04,
#          -1.0315e-02, -1.1330e-02],
#         [ 2.3773e-02,  2.3468e-02, -7.3853e-02,  ...,  4.4800e-02,
#          -9.6802e-02, -3.5126e-02],
#         [-5.1346e-03,  1.9274e-03,  1.5032e-04,  ..., -5.5580e-03,
#          -1.4198e-02,  1.2192e-02]], requires_grad=True), Parameter containing:
# tensor([[ 3.7251e-03, -8.2397e-03, -6.3477e-02,  ..., -1.9409e-02,
#          -6.2084e-04, -4.4769e-02],
#         [-2.9190e-02, -1.4629e-03, -2.0248e-02,  ...,  3.2539e-03,
#           1.3359e-02,  3.3203e-02],
#         [-9.8050e-05, -3.0594e-02, -1.0468e-02,  ..., -1.5900e-02,
#          -1.6525e-02, -2.8687e-02],
#         ...,
#         [-1.1429e-02,  5.1918e-03, -4.0970e-03,  ..., -2.9016e-04,
#          -1.0315e-02, -1.1330e-02],
#         [ 2.3773e-02,  2.3468e-02, -7.3853e-02,  ...,  4.4800e-02,
#          -9.6802e-02, -3.5126e-02],
#         [-5.1346e-03,  1.9274e-03,  1.5032e-04,  ..., -5.5580e-03,
#          -1.4198e-02,  1.2192e-02]], requires_grad=True))
# 参数的值一致
# 模型名称：('encoder.layer.0.attention.output.dense.bias', 'encoder.layer.0.attention.output.dense.bias')
# 参数的值：(Parameter containing:
# tensor([ 0.0696,  0.0378,  0.0334,  ...,  0.0148, -0.0105, -0.0817],
#        requires_grad=True), Parameter containing:
# tensor([ 0.0696,  0.0378,  0.0334,  ...,  0.0148, -0.0105, -0.0817],
#        requires_grad=True))
# 参数的值一致
# 模型名称：('encoder.layer.0.attention.output.LayerNorm.weight', 'encoder.layer.0.attention.output.LayerNorm.weight')
# 参数的值：(Parameter containing:
# tensor([0.9409, 0.9102, 0.8296,  ..., 0.9082, 0.9194, 0.8794],
#        requires_grad=True), Parameter containing:
# tensor([0.9409, 0.9102, 0.8296,  ..., 0.9082, 0.9194, 0.8794],
#        requires_grad=True))
# 参数的值一致
# 模型名称：('encoder.layer.0.attention.output.LayerNorm.bias', 'encoder.layer.0.attention.output.LayerNorm.bias')
# 参数的值：(Parameter containing:
# tensor([-0.2781, -0.3191, -0.0014,  ...,  0.1371,  0.3259, -0.2053],
#        requires_grad=True), Parameter containing:
# tensor([-0.2781, -0.3191, -0.0014,  ...,  0.1371,  0.3259, -0.2053],
#        requires_grad=True))
# 参数的值一致
# 模型名称：('encoder.layer.0.intermediate.dense.weight', 'encoder.layer.0.intermediate.dense.weight')
# 参数的值：(Parameter containing:
# tensor([[-0.0332,  0.0821, -0.0220,  ..., -0.0557, -0.0486, -0.0062],
#         [-0.0395, -0.0009,  0.0163,  ..., -0.0328, -0.0126, -0.0401],
#         [ 0.0217, -0.0010,  0.0052,  ..., -0.0022, -0.0306, -0.0799],
#         ...,
#         [ 0.0453,  0.0505,  0.0333,  ..., -0.0366, -0.0041,  0.0357],
#         [ 0.0222, -0.0093, -0.0088,  ...,  0.0037, -0.0122,  0.0079],
#         [-0.0082, -0.0603,  0.0608,  ..., -0.0163, -0.0275, -0.0143]],
#        requires_grad=True), Parameter containing:
# tensor([[-0.0332,  0.0821, -0.0220,  ..., -0.0557, -0.0486, -0.0062],
#         [-0.0395, -0.0009,  0.0163,  ..., -0.0328, -0.0126, -0.0401],
#         [ 0.0217, -0.0010,  0.0052,  ..., -0.0022, -0.0306, -0.0799],
#         ...,
#         [ 0.0453,  0.0505,  0.0333,  ..., -0.0366, -0.0041,  0.0357],
#         [ 0.0222, -0.0093, -0.0088,  ...,  0.0037, -0.0122,  0.0079],
#         [-0.0082, -0.0603,  0.0608,  ..., -0.0163, -0.0275, -0.0143]],
#        requires_grad=True))
# 参数的值一致
# 模型名称：('encoder.layer.0.intermediate.dense.bias', 'encoder.layer.0.intermediate.dense.bias')
# 参数的值：(Parameter containing:
# tensor([-0.0638, -0.0319, -0.0121,  ...,  0.0420,  0.0365, -0.0097],
#        requires_grad=True), Parameter containing:
# tensor([-0.0638, -0.0319, -0.0121,  ...,  0.0420,  0.0365, -0.0097],
#        requires_grad=True))
# 参数的值一致
# 模型名称：('encoder.layer.0.output.dense.weight', 'encoder.layer.0.output.dense.weight')
# 参数的值：(Parameter containing:
# tensor([[-0.0340, -0.0589,  0.0241,  ...,  0.2861, -0.0362, -0.0466],
#         [ 0.0834, -0.0144,  0.0056,  ...,  0.0450,  0.0120, -0.0680],
#         [-0.0122,  0.0376,  0.0260,  ...,  0.2247, -0.0112,  0.0589],
#         ...,
#         [ 0.0015,  0.0588, -0.0159,  ..., -0.1198,  0.0351, -0.0402],
#         [ 0.0292, -0.0267, -0.0398,  ...,  0.2002,  0.0305, -0.0826],
#         [ 0.0729, -0.0230, -0.0039,  ...,  0.0529, -0.0377, -0.0822]],
#        requires_grad=True), Parameter containing:
# tensor([[-0.0340, -0.0589,  0.0241,  ...,  0.2861, -0.0362, -0.0466],
#         [ 0.0834, -0.0144,  0.0056,  ...,  0.0450,  0.0120, -0.0680],
#         [-0.0122,  0.0376,  0.0260,  ...,  0.2247, -0.0112,  0.0589],
#         ...,
#         [ 0.0015,  0.0588, -0.0159,  ..., -0.1198,  0.0351, -0.0402],
#         [ 0.0292, -0.0267, -0.0398,  ...,  0.2002,  0.0305, -0.0826],
#         [ 0.0729, -0.0230, -0.0039,  ...,  0.0529, -0.0377, -0.0822]],
#        requires_grad=True))
# 参数的值一致
# 模型名称：('encoder.layer.0.output.dense.bias', 'encoder.layer.0.output.dense.bias')
# 参数的值：(Parameter containing:
# tensor([ 0.0654,  0.0360, -0.0465,  ..., -0.0346, -0.1163,  0.0012],
#        requires_grad=True), Parameter containing:
# tensor([ 0.0654,  0.0360, -0.0465,  ..., -0.0346, -0.1163,  0.0012],
#        requires_grad=True))
# 参数的值一致
# 模型名称：('encoder.layer.0.output.LayerNorm.weight', 'encoder.layer.0.output.LayerNorm.weight')
# 参数的值：(Parameter containing:
# tensor([0.9224, 0.9194, 0.8696,  ..., 0.9033, 0.9307, 0.8711],
#        requires_grad=True), Parameter containing:
# tensor([0.9224, 0.9194, 0.8696,  ..., 0.9033, 0.9307, 0.8711],
#        requires_grad=True))
# 参数的值一致
# 模型名称：('encoder.layer.0.output.LayerNorm.bias', 'encoder.layer.0.output.LayerNorm.bias')
# 参数的值：(Parameter containing:
# tensor([ 0.1228,  0.1675, -0.0591,  ..., -0.0922, -0.1831,  0.0930],
#        requires_grad=True), Parameter containing:
# tensor([ 0.1228,  0.1675, -0.0591,  ..., -0.0922, -0.1831,  0.0930],
#        requires_grad=True))
# 参数的值一致
# 模型名称：('encoder.layer.1.attention.self.query.weight', 'encoder.layer.1.attention.self.query.weight')
# 参数的值：(Parameter containing:
# tensor([[-0.0499,  0.0575, -0.1956,  ...,  0.0719, -0.0213,  0.0309],
#         [-0.0060, -0.0704,  0.0183,  ..., -0.0650,  0.0337,  0.0238],
#         [-0.0450, -0.0731,  0.0148,  ..., -0.0498, -0.0479, -0.0186],
#         ...,
#         [ 0.0716,  0.0156,  0.0200,  ...,  0.0386, -0.0717,  0.0390],
#         [-0.0670, -0.0387, -0.0633,  ...,  0.0064, -0.0230, -0.0049],
#         [-0.0296, -0.0117,  0.0358,  ..., -0.0548, -0.0201,  0.0205]],
#        requires_grad=True), Parameter containing:
# tensor([[-0.0499,  0.0575, -0.1956,  ...,  0.0719, -0.0213,  0.0309],
#         [-0.0060, -0.0704,  0.0183,  ..., -0.0650,  0.0337,  0.0238],
#         [-0.0450, -0.0731,  0.0148,  ..., -0.0498, -0.0479, -0.0186],
#         ...,
#         [ 0.0716,  0.0156,  0.0200,  ...,  0.0386, -0.0717,  0.0390],
#         [-0.0670, -0.0387, -0.0633,  ...,  0.0064, -0.0230, -0.0049],
#         [-0.0296, -0.0117,  0.0358,  ..., -0.0548, -0.0201,  0.0205]],
#        requires_grad=True))
# 参数的值一致
# 模型名称：('encoder.layer.1.attention.self.query.bias', 'encoder.layer.1.attention.self.query.bias')
# 参数的值：(Parameter containing:
# tensor([-0.1247,  0.2119, -0.3367,  ...,  0.0138, -0.1132, -0.1871],
#        requires_grad=True), Parameter containing:
# tensor([-0.1247,  0.2119, -0.3367,  ...,  0.0138, -0.1132, -0.1871],
#        requires_grad=True))
# 参数的值一致
# 模型名称：('encoder.layer.1.attention.self.key.weight', 'encoder.layer.1.attention.self.key.weight')
# 参数的值：(Parameter containing:
# tensor([[ 0.0237,  0.0258,  0.0054,  ...,  0.0553,  0.0838, -0.0098],
#         [ 0.0294,  0.0734,  0.0559,  ..., -0.1073, -0.1132,  0.0687],
#         [-0.0376, -0.0038,  0.0782,  ..., -0.0034,  0.0182, -0.0315],
#         ...,
#         [ 0.0095,  0.0097,  0.0075,  ..., -0.0299, -0.0131,  0.0760],
#         [-0.0717,  0.0030,  0.0531,  ...,  0.0030,  0.0759,  0.0777],
#         [ 0.0133,  0.0045,  0.0064,  ...,  0.0166,  0.0477,  0.0444]],
#        requires_grad=True), Parameter containing:
# tensor([[ 0.0237,  0.0258,  0.0054,  ...,  0.0553,  0.0838, -0.0098],
#         [ 0.0294,  0.0734,  0.0559,  ..., -0.1073, -0.1132,  0.0687],
#         [-0.0376, -0.0038,  0.0782,  ..., -0.0034,  0.0182, -0.0315],
#         ...,
#         [ 0.0095,  0.0097,  0.0075,  ..., -0.0299, -0.0131,  0.0760],
#         [-0.0717,  0.0030,  0.0531,  ...,  0.0030,  0.0759,  0.0777],
#         [ 0.0133,  0.0045,  0.0064,  ...,  0.0166,  0.0477,  0.0444]],
#        requires_grad=True))
# 参数的值一致
# 模型名称：('encoder.layer.1.attention.self.key.bias', 'encoder.layer.1.attention.self.key.bias')
# 参数的值：(Parameter containing:
# tensor([ 0.2898, -0.2761,  0.0284,  ..., -0.0922,  0.1311, -0.2437],
#        requires_grad=True), Parameter containing:
# tensor([ 0.2898, -0.2761,  0.0284,  ..., -0.0922,  0.1311, -0.2437],
#        requires_grad=True))
# 参数的值一致
# 模型名称：('encoder.layer.1.attention.self.value.weight', 'encoder.layer.1.attention.self.value.weight')
# 参数的值：(Parameter containing:
# tensor([[-0.0185,  0.0016,  0.0143,  ...,  0.0117, -0.0143, -0.0515],
#         [-0.0096, -0.0093,  0.0002,  ..., -0.0060,  0.0111, -0.0511],
#         [-0.0359,  0.0028,  0.0231,  ..., -0.0226,  0.0098, -0.0239],
#         ...,
#         [ 0.0038, -0.0403,  0.0085,  ...,  0.0358,  0.0306,  0.0456],
#         [ 0.0137,  0.0136, -0.0065,  ..., -0.0378,  0.0218,  0.0155],
#         [-0.0045, -0.0021,  0.0079,  ..., -0.0267, -0.0095,  0.0063]],
#        requires_grad=True), Parameter containing:
# tensor([[-0.0185,  0.0016,  0.0143,  ...,  0.0117, -0.0143, -0.0515],
#         [-0.0096, -0.0093,  0.0002,  ..., -0.0060,  0.0111, -0.0511],
#         [-0.0359,  0.0028,  0.0231,  ..., -0.0226,  0.0098, -0.0239],
#         ...,
#         [ 0.0038, -0.0403,  0.0085,  ...,  0.0358,  0.0306,  0.0456],
#         [ 0.0137,  0.0136, -0.0065,  ..., -0.0378,  0.0218,  0.0155],
#         [-0.0045, -0.0021,  0.0079,  ..., -0.0267, -0.0095,  0.0063]],
#        requires_grad=True))
# 参数的值一致
# 模型名称：('encoder.layer.1.attention.self.value.bias', 'encoder.layer.1.attention.self.value.bias')
# 参数的值：(Parameter containing:
# tensor([ 0.0027,  0.0004,  0.0026,  ..., -0.0024, -0.0002, -0.0089],
#        requires_grad=True), Parameter containing:
# tensor([ 0.0027,  0.0004,  0.0026,  ..., -0.0024, -0.0002, -0.0089],
#        requires_grad=True))
# 参数的值一致
# 模型名称：('encoder.layer.1.attention.output.dense.weight', 'encoder.layer.1.attention.output.dense.weight')
# 参数的值：(Parameter containing:
# tensor([[ 0.0800, -0.0067,  0.0525,  ...,  0.0880,  0.0062,  0.0146],
#         [-0.0222,  0.0030,  0.0245,  ...,  0.0468, -0.0067,  0.0046],
#         [ 0.0290, -0.0153,  0.0243,  ...,  0.0698, -0.0343,  0.0115],
#         ...,
#         [-0.0414,  0.0096,  0.0197,  ..., -0.0014, -0.0249,  0.0127],
#         [ 0.0202, -0.0052,  0.0084,  ...,  0.0279,  0.0014, -0.0149],
#         [ 0.0679,  0.0019,  0.0095,  ...,  0.0470,  0.0049,  0.0050]],
#        requires_grad=True), Parameter containing:
# tensor([[ 0.0800, -0.0067,  0.0525,  ...,  0.0880,  0.0062,  0.0146],
#         [-0.0222,  0.0030,  0.0245,  ...,  0.0468, -0.0067,  0.0046],
#         [ 0.0290, -0.0153,  0.0243,  ...,  0.0698, -0.0343,  0.0115],
#         ...,
#         [-0.0414,  0.0096,  0.0197,  ..., -0.0014, -0.0249,  0.0127],
#         [ 0.0202, -0.0052,  0.0084,  ...,  0.0279,  0.0014, -0.0149],
#         [ 0.0679,  0.0019,  0.0095,  ...,  0.0470,  0.0049,  0.0050]],
#        requires_grad=True))
# 参数的值一致
# 模型名称：('encoder.layer.1.attention.output.dense.bias', 'encoder.layer.1.attention.output.dense.bias')
# 参数的值：(Parameter containing:
# tensor([ 0.0577,  0.0787, -0.0606,  ...,  0.0209, -0.0662, -0.0997],
#        requires_grad=True), Parameter containing:
# tensor([ 0.0577,  0.0787, -0.0606,  ...,  0.0209, -0.0662, -0.0997],
#        requires_grad=True))
# 参数的值一致
# 模型名称：('encoder.layer.1.attention.output.LayerNorm.weight', 'encoder.layer.1.attention.output.LayerNorm.weight')
# 参数的值：(Parameter containing:
# tensor([0.9370, 0.9346, 0.8833,  ..., 0.9375, 0.9556, 0.9312],
#        requires_grad=True), Parameter containing:
# tensor([0.9370, 0.9346, 0.8833,  ..., 0.9375, 0.9556, 0.9312],
#        requires_grad=True))
# 参数的值一致
# 模型名称：('encoder.layer.1.attention.output.LayerNorm.bias', 'encoder.layer.1.attention.output.LayerNorm.bias')
# 参数的值：(Parameter containing:
# tensor([ 0.1520, -0.1035,  0.0467,  ...,  0.3530,  0.4338,  0.2499],
#        requires_grad=True), Parameter containing:
# tensor([ 0.1520, -0.1035,  0.0467,  ...,  0.3530,  0.4338,  0.2499],
#        requires_grad=True))
# 参数的值一致
# 模型名称：('encoder.layer.1.intermediate.dense.weight', 'encoder.layer.1.intermediate.dense.weight')
# 参数的值：(Parameter containing:
# tensor([[ 1.7334e-02, -2.6679e-04,  5.7678e-02,  ..., -3.5461e-02,
#          -2.1698e-02, -1.3695e-02],
#         [-3.7441e-03,  5.7098e-02,  2.7496e-02,  ...,  6.2744e-02,
#          -5.6213e-02, -1.0870e-01],
#         [-5.3284e-02,  1.4062e-01,  6.7261e-02,  ..., -1.1383e-02,
#          -3.3173e-02, -7.6294e-02],
#         ...,
#         [-4.2084e-02,  7.7087e-02, -9.9540e-05,  ..., -8.0872e-02,
#          -4.5593e-02,  2.2186e-02],
#         [-4.8218e-02,  1.0735e-02,  1.8097e-02,  ...,  1.6495e-02,
#          -1.6203e-03, -3.2898e-02],
#         [ 1.8433e-02, -1.0309e-03,  5.9795e-04,  ...,  5.8472e-02,
#          -4.9622e-02, -6.4392e-02]], requires_grad=True), Parameter containing:
# tensor([[ 1.7334e-02, -2.6679e-04,  5.7678e-02,  ..., -3.5461e-02,
#          -2.1698e-02, -1.3695e-02],
#         [-3.7441e-03,  5.7098e-02,  2.7496e-02,  ...,  6.2744e-02,
#          -5.6213e-02, -1.0870e-01],
#         [-5.3284e-02,  1.4062e-01,  6.7261e-02,  ..., -1.1383e-02,
#          -3.3173e-02, -7.6294e-02],
#         ...,
#         [-4.2084e-02,  7.7087e-02, -9.9540e-05,  ..., -8.0872e-02,
#          -4.5593e-02,  2.2186e-02],
#         [-4.8218e-02,  1.0735e-02,  1.8097e-02,  ...,  1.6495e-02,
#          -1.6203e-03, -3.2898e-02],
#         [ 1.8433e-02, -1.0309e-03,  5.9795e-04,  ...,  5.8472e-02,
#          -4.9622e-02, -6.4392e-02]], requires_grad=True))
# 参数的值一致
# 模型名称：('encoder.layer.1.intermediate.dense.bias', 'encoder.layer.1.intermediate.dense.bias')
# 参数的值：(Parameter containing:
# tensor([-6.1859e-02, -8.1543e-02, -6.6757e-05,  ..., -8.0505e-02,
#         -5.1765e-03,  1.3680e-02], requires_grad=True), Parameter containing:
# tensor([-6.1859e-02, -8.1543e-02, -6.6757e-05,  ..., -8.0505e-02,
#         -5.1765e-03,  1.3680e-02], requires_grad=True))
# 参数的值一致
# 模型名称：('encoder.layer.1.output.dense.weight', 'encoder.layer.1.output.dense.weight')
# 参数的值：(Parameter containing:
# tensor([[ 0.0841,  0.0421, -0.0111,  ...,  0.0459, -0.0211, -0.0238],
#         [ 0.0216, -0.0251, -0.0196,  ..., -0.0325, -0.0350, -0.0217],
#         [ 0.0962, -0.0520, -0.0604,  ..., -0.0206,  0.0196,  0.0124],
#         ...,
#         [ 0.0463, -0.0535, -0.0049,  ...,  0.0571,  0.0715,  0.0259],
#         [-0.0102,  0.0750, -0.0094,  ...,  0.0385,  0.0404, -0.0219],
#         [ 0.0456,  0.0085, -0.0315,  ...,  0.0321,  0.0068,  0.0284]],
#        requires_grad=True), Parameter containing:
# tensor([[ 0.0841,  0.0421, -0.0111,  ...,  0.0459, -0.0211, -0.0238],
#         [ 0.0216, -0.0251, -0.0196,  ..., -0.0325, -0.0350, -0.0217],
#         [ 0.0962, -0.0520, -0.0604,  ..., -0.0206,  0.0196,  0.0124],
#         ...,
#         [ 0.0463, -0.0535, -0.0049,  ...,  0.0571,  0.0715,  0.0259],
#         [-0.0102,  0.0750, -0.0094,  ...,  0.0385,  0.0404, -0.0219],
#         [ 0.0456,  0.0085, -0.0315,  ...,  0.0321,  0.0068,  0.0284]],
#        requires_grad=True))
# 参数的值一致
# 模型名称：('encoder.layer.1.output.dense.bias', 'encoder.layer.1.output.dense.bias')
# 参数的值：(Parameter containing:
# tensor([ 0.0140, -0.0025, -0.0790,  ...,  0.0070, -0.0467,  0.0079],
#        requires_grad=True), Parameter containing:
# tensor([ 0.0140, -0.0025, -0.0790,  ...,  0.0070, -0.0467,  0.0079],
#        requires_grad=True))
# 参数的值一致
# 模型名称：('encoder.layer.1.output.LayerNorm.weight', 'encoder.layer.1.output.LayerNorm.weight')
# 参数的值：(Parameter containing:
# tensor([0.9194, 0.9355, 0.9009,  ..., 0.9146, 0.9487, 0.8936],
#        requires_grad=True), Parameter containing:
# tensor([0.9194, 0.9355, 0.9009,  ..., 0.9146, 0.9487, 0.8936],
#        requires_grad=True))
# 参数的值一致
# 模型名称：('encoder.layer.1.output.LayerNorm.bias', 'encoder.layer.1.output.LayerNorm.bias')
# 参数的值：(Parameter containing:
# tensor([ 0.0527,  0.2632,  0.1323,  ..., -0.0981, -0.1317,  0.0252],
#        requires_grad=True), Parameter containing:
# tensor([ 0.0527,  0.2632,  0.1323,  ..., -0.0981, -0.1317,  0.0252],
#        requires_grad=True))
# 参数的值一致
# 模型名称：('encoder.layer.2.attention.self.query.weight', 'encoder.layer.2.attention.self.query.weight')
# 参数的值：(Parameter containing:
# tensor([[-0.0282,  0.0112,  0.0383,  ...,  0.0969,  0.0311,  0.0279],
#         [-0.0587,  0.0002, -0.0505,  ..., -0.0333,  0.0613, -0.0549],
#         [ 0.0361, -0.0729, -0.0592,  ...,  0.0061, -0.0390,  0.0111],
#         ...,
#         [-0.0529, -0.0228, -0.0496,  ..., -0.0617, -0.0340, -0.0300],
#         [ 0.0209,  0.0166, -0.0478,  ..., -0.0161,  0.0688, -0.0715],
#         [ 0.0066,  0.1191, -0.0064,  ...,  0.0146,  0.0101, -0.0751]],
#        requires_grad=True), Parameter containing:
# tensor([[-0.0282,  0.0112,  0.0383,  ...,  0.0969,  0.0311,  0.0279],
#         [-0.0587,  0.0002, -0.0505,  ..., -0.0333,  0.0613, -0.0549],
#         [ 0.0361, -0.0729, -0.0592,  ...,  0.0061, -0.0390,  0.0111],
#         ...,
#         [-0.0529, -0.0228, -0.0496,  ..., -0.0617, -0.0340, -0.0300],
#         [ 0.0209,  0.0166, -0.0478,  ..., -0.0161,  0.0688, -0.0715],
#         [ 0.0066,  0.1191, -0.0064,  ...,  0.0146,  0.0101, -0.0751]],
#        requires_grad=True))
# 参数的值一致
# 模型名称：('encoder.layer.2.attention.self.query.bias', 'encoder.layer.2.attention.self.query.bias')
# 参数的值：(Parameter containing:
# tensor([-0.3574,  0.0430, -0.0534,  ..., -0.0562, -0.0135, -0.0047],
#        requires_grad=True), Parameter containing:
# tensor([-0.3574,  0.0430, -0.0534,  ..., -0.0562, -0.0135, -0.0047],
#        requires_grad=True))
# 参数的值一致
# 模型名称：('encoder.layer.2.attention.self.key.weight', 'encoder.layer.2.attention.self.key.weight')
# 参数的值：(Parameter containing:
# tensor([[ 0.0226, -0.0132, -0.0091,  ...,  0.0717, -0.0468, -0.0072],
#         [ 0.0592,  0.0428,  0.0429,  ...,  0.0176, -0.0405,  0.1145],
#         [ 0.0307, -0.0151, -0.0106,  ...,  0.0056,  0.0017,  0.0110],
#         ...,
#         [ 0.0706,  0.0381,  0.0105,  ..., -0.0108,  0.0151,  0.0113],
#         [ 0.0211, -0.0633,  0.0274,  ..., -0.0480, -0.0768, -0.0314],
#         [ 0.0213, -0.0122,  0.0675,  ..., -0.0673, -0.0634,  0.0103]],
#        requires_grad=True), Parameter containing:
# tensor([[ 0.0226, -0.0132, -0.0091,  ...,  0.0717, -0.0468, -0.0072],
#         [ 0.0592,  0.0428,  0.0429,  ...,  0.0176, -0.0405,  0.1145],
#         [ 0.0307, -0.0151, -0.0106,  ...,  0.0056,  0.0017,  0.0110],
#         ...,
#         [ 0.0706,  0.0381,  0.0105,  ..., -0.0108,  0.0151,  0.0113],
#         [ 0.0211, -0.0633,  0.0274,  ..., -0.0480, -0.0768, -0.0314],
#         [ 0.0213, -0.0122,  0.0675,  ..., -0.0673, -0.0634,  0.0103]],
#        requires_grad=True))
# 参数的值一致
# 模型名称：('encoder.layer.2.attention.self.key.bias', 'encoder.layer.2.attention.self.key.bias')
# 参数的值：(Parameter containing:
# tensor([-0.0275, -0.1592, -0.0629,  ...,  0.3296,  0.0713,  0.2344],
#        requires_grad=True), Parameter containing:
# tensor([-0.0275, -0.1592, -0.0629,  ...,  0.3296,  0.0713,  0.2344],
#        requires_grad=True))
# 参数的值一致
# 模型名称：('encoder.layer.2.attention.self.value.weight', 'encoder.layer.2.attention.self.value.weight')
# 参数的值：(Parameter containing:
# tensor([[ 8.1024e-03,  1.1093e-02,  2.6642e-02,  ..., -2.7313e-02,
#           9.8419e-03,  2.1042e-02],
#         [-1.0307e-02,  3.2867e-02, -1.0364e-01,  ..., -3.6865e-02,
#           4.0527e-02,  1.0628e-02],
#         [ 2.2369e-02,  2.6276e-02,  3.1219e-02,  ..., -3.4698e-02,
#          -4.5776e-02,  2.0386e-02],
#         ...,
#         [-4.4327e-03, -2.8503e-02, -2.3842e-07,  ...,  1.3893e-02,
#           2.4460e-02, -4.9316e-02],
#         [ 1.9363e-02,  1.1276e-02, -5.0140e-02,  ...,  1.1841e-02,
#           1.6571e-02, -1.5495e-02],
#         [ 2.1622e-02,  6.0463e-03, -2.4780e-02,  ...,  2.3010e-02,
#           1.5411e-02, -4.1626e-02]], requires_grad=True), Parameter containing:
# tensor([[ 8.1024e-03,  1.1093e-02,  2.6642e-02,  ..., -2.7313e-02,
#           9.8419e-03,  2.1042e-02],
#         [-1.0307e-02,  3.2867e-02, -1.0364e-01,  ..., -3.6865e-02,
#           4.0527e-02,  1.0628e-02],
#         [ 2.2369e-02,  2.6276e-02,  3.1219e-02,  ..., -3.4698e-02,
#          -4.5776e-02,  2.0386e-02],
#         ...,
#         [-4.4327e-03, -2.8503e-02, -2.3842e-07,  ...,  1.3893e-02,
#           2.4460e-02, -4.9316e-02],
#         [ 1.9363e-02,  1.1276e-02, -5.0140e-02,  ...,  1.1841e-02,
#           1.6571e-02, -1.5495e-02],
#         [ 2.1622e-02,  6.0463e-03, -2.4780e-02,  ...,  2.3010e-02,
#           1.5411e-02, -4.1626e-02]], requires_grad=True))
# 参数的值一致
# 模型名称：('encoder.layer.2.attention.self.value.bias', 'encoder.layer.2.attention.self.value.bias')
# 参数的值：(Parameter containing:
# tensor([-0.0011,  0.0037, -0.0058,  ...,  0.0017,  0.0007,  0.0212],
#        requires_grad=True), Parameter containing:
# tensor([-0.0011,  0.0037, -0.0058,  ...,  0.0017,  0.0007,  0.0212],
#        requires_grad=True))
# 参数的值一致
# 模型名称：('encoder.layer.2.attention.output.dense.weight', 'encoder.layer.2.attention.output.dense.weight')
# 参数的值：(Parameter containing:
# tensor([[-0.0389,  0.0065, -0.0111,  ...,  0.0060, -0.0042,  0.0324],
#         [-0.0154, -0.0277, -0.0273,  ...,  0.0364,  0.0394, -0.0088],
#         [ 0.0186,  0.0095, -0.0027,  ..., -0.0191, -0.0229, -0.0053],
#         ...,
#         [ 0.0576,  0.0006,  0.0311,  ...,  0.0196,  0.0173, -0.0112],
#         [ 0.0165,  0.0071,  0.0201,  ..., -0.0051, -0.0124,  0.0337],
#         [-0.0173, -0.0100, -0.0258,  ...,  0.0209,  0.0129,  0.0168]],
#        requires_grad=True), Parameter containing:
# tensor([[-0.0389,  0.0065, -0.0111,  ...,  0.0060, -0.0042,  0.0324],
#         [-0.0154, -0.0277, -0.0273,  ...,  0.0364,  0.0394, -0.0088],
#         [ 0.0186,  0.0095, -0.0027,  ..., -0.0191, -0.0229, -0.0053],
#         ...,
#         [ 0.0576,  0.0006,  0.0311,  ...,  0.0196,  0.0173, -0.0112],
#         [ 0.0165,  0.0071,  0.0201,  ..., -0.0051, -0.0124,  0.0337],
#         [-0.0173, -0.0100, -0.0258,  ...,  0.0209,  0.0129,  0.0168]],
#        requires_grad=True))
# 参数的值一致
# 模型名称：('encoder.layer.2.attention.output.dense.bias', 'encoder.layer.2.attention.output.dense.bias')
# 参数的值：(Parameter containing:
# tensor([ 0.0396,  0.0716, -0.0672,  ...,  0.0225, -0.0558,  0.0090],
#        requires_grad=True), Parameter containing:
# tensor([ 0.0396,  0.0716, -0.0672,  ...,  0.0225, -0.0558,  0.0090],
#        requires_grad=True))
# 参数的值一致
# 模型名称：('encoder.layer.2.attention.output.LayerNorm.weight', 'encoder.layer.2.attention.output.LayerNorm.weight')
# 参数的值：(Parameter containing:
# tensor([0.9639, 0.8975, 0.9106,  ..., 0.9214, 0.9424, 0.9312],
#        requires_grad=True), Parameter containing:
# tensor([0.9639, 0.8975, 0.9106,  ..., 0.9214, 0.9424, 0.9312],
#        requires_grad=True))
# 参数的值一致
# 模型名称：('encoder.layer.2.attention.output.LayerNorm.bias', 'encoder.layer.2.attention.output.LayerNorm.bias')
# 参数的值：(Parameter containing:
# tensor([0.2408, 0.2106, 0.2776,  ..., 0.3035, 0.2930, 0.2708],
#        requires_grad=True), Parameter containing:
# tensor([0.2408, 0.2106, 0.2776,  ..., 0.3035, 0.2930, 0.2708],
#        requires_grad=True))
# 参数的值一致
# 模型名称：('encoder.layer.2.intermediate.dense.weight', 'encoder.layer.2.intermediate.dense.weight')
# 参数的值：(Parameter containing:
# tensor([[ 0.0261,  0.0392,  0.0259,  ...,  0.0290, -0.0101, -0.0930],
#         [-0.0127, -0.0650, -0.0376,  ..., -0.0131,  0.0023, -0.0338],
#         [-0.0254, -0.1156, -0.0443,  ..., -0.0072, -0.0005,  0.0356],
#         ...,
#         [ 0.0347,  0.0256,  0.0059,  ..., -0.0007, -0.0116, -0.0880],
#         [-0.0480, -0.0432, -0.0518,  ..., -0.0439,  0.0271, -0.0742],
#         [ 0.0571,  0.0914, -0.0428,  ..., -0.0232, -0.0819, -0.0316]],
#        requires_grad=True), Parameter containing:
# tensor([[ 0.0261,  0.0392,  0.0259,  ...,  0.0290, -0.0101, -0.0930],
#         [-0.0127, -0.0650, -0.0376,  ..., -0.0131,  0.0023, -0.0338],
#         [-0.0254, -0.1156, -0.0443,  ..., -0.0072, -0.0005,  0.0356],
#         ...,
#         [ 0.0347,  0.0256,  0.0059,  ..., -0.0007, -0.0116, -0.0880],
#         [-0.0480, -0.0432, -0.0518,  ..., -0.0439,  0.0271, -0.0742],
#         [ 0.0571,  0.0914, -0.0428,  ..., -0.0232, -0.0819, -0.0316]],
#        requires_grad=True))
# 参数的值一致
# 模型名称：('encoder.layer.2.intermediate.dense.bias', 'encoder.layer.2.intermediate.dense.bias')
# 参数的值：(Parameter containing:
# tensor([-0.0884,  0.0016, -0.0733,  ..., -0.0286, -0.0183, -0.0533],
#        requires_grad=True), Parameter containing:
# tensor([-0.0884,  0.0016, -0.0733,  ..., -0.0286, -0.0183, -0.0533],
#        requires_grad=True))
# 参数的值一致
# 模型名称：('encoder.layer.2.output.dense.weight', 'encoder.layer.2.output.dense.weight')
# 参数的值：(Parameter containing:
# tensor([[-0.0140,  0.0087, -0.0201,  ...,  0.0558, -0.0178,  0.0357],
#         [-0.0066,  0.0002,  0.0279,  ..., -0.0201, -0.0367,  0.0622],
#         [ 0.0064,  0.0290,  0.0741,  ...,  0.0378, -0.0175, -0.1109],
#         ...,
#         [ 0.0159,  0.0529, -0.0200,  ..., -0.0032,  0.0053,  0.0907],
#         [-0.0090, -0.0221, -0.0008,  ..., -0.0170, -0.0534, -0.0719],
#         [ 0.0098, -0.0356, -0.0079,  ..., -0.0144,  0.0084, -0.0925]],
#        requires_grad=True), Parameter containing:
# tensor([[-0.0140,  0.0087, -0.0201,  ...,  0.0558, -0.0178,  0.0357],
#         [-0.0066,  0.0002,  0.0279,  ..., -0.0201, -0.0367,  0.0622],
#         [ 0.0064,  0.0290,  0.0741,  ...,  0.0378, -0.0175, -0.1109],
#         ...,
#         [ 0.0159,  0.0529, -0.0200,  ..., -0.0032,  0.0053,  0.0907],
#         [-0.0090, -0.0221, -0.0008,  ..., -0.0170, -0.0534, -0.0719],
#         [ 0.0098, -0.0356, -0.0079,  ..., -0.0144,  0.0084, -0.0925]],
#        requires_grad=True))
# 参数的值一致
# 模型名称：('encoder.layer.2.output.dense.bias', 'encoder.layer.2.output.dense.bias')
# 参数的值：(Parameter containing:
# tensor([ 0.0541,  0.0134, -0.0452,  ..., -0.0027, -0.0667,  0.0242],
#        requires_grad=True), Parameter containing:
# tensor([ 0.0541,  0.0134, -0.0452,  ..., -0.0027, -0.0667,  0.0242],
#        requires_grad=True))
# 参数的值一致
# 模型名称：('encoder.layer.2.output.LayerNorm.weight', 'encoder.layer.2.output.LayerNorm.weight')
# 参数的值：(Parameter containing:
# tensor([0.9492, 0.9082, 0.9170,  ..., 0.8984, 0.9458, 0.9194],
#        requires_grad=True), Parameter containing:
# tensor([0.9492, 0.9082, 0.9170,  ..., 0.8984, 0.9458, 0.9194],
#        requires_grad=True))
# 参数的值一致
# 模型名称：('encoder.layer.2.output.LayerNorm.bias', 'encoder.layer.2.output.LayerNorm.bias')
# 参数的值：(Parameter containing:
# tensor([ 0.0006,  0.0635, -0.0493,  ..., -0.0773, -0.0945, -0.0644],
#        requires_grad=True), Parameter containing:
# tensor([ 0.0006,  0.0635, -0.0493,  ..., -0.0773, -0.0945, -0.0644],
#        requires_grad=True))
# 参数的值一致
# 模型名称：('encoder.layer.3.attention.self.query.weight', 'encoder.layer.3.attention.self.query.weight')
# 参数的值：(Parameter containing:
# tensor([[ 0.0357, -0.0264, -0.0163,  ...,  0.0188, -0.0964, -0.0027],
#         [-0.0730,  0.0329, -0.0037,  ..., -0.0596, -0.0045, -0.0598],
#         [-0.0050,  0.0447, -0.0013,  ..., -0.0593,  0.0124,  0.0521],
#         ...,
#         [ 0.1170, -0.0448, -0.1074,  ..., -0.0031, -0.0327, -0.0897],
#         [-0.0555, -0.0145,  0.0027,  ..., -0.0977,  0.0393, -0.0133],
#         [ 0.0294, -0.0485,  0.0318,  ..., -0.1148, -0.0814, -0.0350]],
#        requires_grad=True), Parameter containing:
# tensor([[ 0.0357, -0.0264, -0.0163,  ...,  0.0188, -0.0964, -0.0027],
#         [-0.0730,  0.0329, -0.0037,  ..., -0.0596, -0.0045, -0.0598],
#         [-0.0050,  0.0447, -0.0013,  ..., -0.0593,  0.0124,  0.0521],
#         ...,
#         [ 0.1170, -0.0448, -0.1074,  ..., -0.0031, -0.0327, -0.0897],
#         [-0.0555, -0.0145,  0.0027,  ..., -0.0977,  0.0393, -0.0133],
#         [ 0.0294, -0.0485,  0.0318,  ..., -0.1148, -0.0814, -0.0350]],
#        requires_grad=True))
# 参数的值一致
# 模型名称：('encoder.layer.3.attention.self.query.bias', 'encoder.layer.3.attention.self.query.bias')
# 参数的值：(Parameter containing:
# tensor([-0.0912, -0.1627,  0.0135,  ..., -0.0506, -0.0742, -0.1385],
#        requires_grad=True), Parameter containing:
# tensor([-0.0912, -0.1627,  0.0135,  ..., -0.0506, -0.0742, -0.1385],
#        requires_grad=True))
# 参数的值一致
# 模型名称：('encoder.layer.3.attention.self.key.weight', 'encoder.layer.3.attention.self.key.weight')
# 参数的值：(Parameter containing:
# tensor([[-0.0305, -0.0493,  0.0422,  ..., -0.0168, -0.0517,  0.0632],
#         [-0.0204,  0.0149, -0.0665,  ...,  0.0185,  0.0199,  0.0503],
#         [-0.0637,  0.0497,  0.0211,  ..., -0.0226, -0.0155,  0.0317],
#         ...,
#         [ 0.0392,  0.0152,  0.0388,  ...,  0.0221, -0.0473, -0.1290],
#         [ 0.0278, -0.0739, -0.0214,  ..., -0.0448, -0.0733, -0.0404],
#         [ 0.0269, -0.0258,  0.0508,  ...,  0.0227, -0.0681,  0.0185]],
#        requires_grad=True), Parameter containing:
# tensor([[-0.0305, -0.0493,  0.0422,  ..., -0.0168, -0.0517,  0.0632],
#         [-0.0204,  0.0149, -0.0665,  ...,  0.0185,  0.0199,  0.0503],
#         [-0.0637,  0.0497,  0.0211,  ..., -0.0226, -0.0155,  0.0317],
#         ...,
#         [ 0.0392,  0.0152,  0.0388,  ...,  0.0221, -0.0473, -0.1290],
#         [ 0.0278, -0.0739, -0.0214,  ..., -0.0448, -0.0733, -0.0404],
#         [ 0.0269, -0.0258,  0.0508,  ...,  0.0227, -0.0681,  0.0185]],
#        requires_grad=True))
# 参数的值一致
# 模型名称：('encoder.layer.3.attention.self.key.bias', 'encoder.layer.3.attention.self.key.bias')
# 参数的值：(Parameter containing:
# tensor([-0.2104,  0.1335, -0.2400,  ..., -0.2153, -0.1667,  0.0795],
#        requires_grad=True), Parameter containing:
# tensor([-0.2104,  0.1335, -0.2400,  ..., -0.2153, -0.1667,  0.0795],
#        requires_grad=True))
# 参数的值一致
# 模型名称：('encoder.layer.3.attention.self.value.weight', 'encoder.layer.3.attention.self.value.weight')
# 参数的值：(Parameter containing:
# tensor([[ 0.0326,  0.0227, -0.0185,  ...,  0.0302, -0.0009, -0.0207],
#         [-0.0052, -0.0256,  0.0089,  ...,  0.0190,  0.0176,  0.0397],
#         [-0.0137, -0.0006,  0.0181,  ...,  0.0189,  0.0020, -0.0011],
#         ...,
#         [ 0.0137,  0.0059,  0.0044,  ...,  0.0026,  0.0557, -0.0067],
#         [-0.0391, -0.0937,  0.0446,  ...,  0.0449,  0.0102, -0.0767],
#         [-0.0014, -0.0986, -0.0683,  ...,  0.0198, -0.0129,  0.0192]],
#        requires_grad=True), Parameter containing:
# tensor([[ 0.0326,  0.0227, -0.0185,  ...,  0.0302, -0.0009, -0.0207],
#         [-0.0052, -0.0256,  0.0089,  ...,  0.0190,  0.0176,  0.0397],
#         [-0.0137, -0.0006,  0.0181,  ...,  0.0189,  0.0020, -0.0011],
#         ...,
#         [ 0.0137,  0.0059,  0.0044,  ...,  0.0026,  0.0557, -0.0067],
#         [-0.0391, -0.0937,  0.0446,  ...,  0.0449,  0.0102, -0.0767],
#         [-0.0014, -0.0986, -0.0683,  ...,  0.0198, -0.0129,  0.0192]],
#        requires_grad=True))
# 参数的值一致
# 模型名称：('encoder.layer.3.attention.self.value.bias', 'encoder.layer.3.attention.self.value.bias')
# 参数的值：(Parameter containing:
# tensor([-0.0035,  0.0064, -0.0021,  ..., -0.0070,  0.0037, -0.0080],
#        requires_grad=True), Parameter containing:
# tensor([-0.0035,  0.0064, -0.0021,  ..., -0.0070,  0.0037, -0.0080],
#        requires_grad=True))
# 参数的值一致
# 模型名称：('encoder.layer.3.attention.output.dense.weight', 'encoder.layer.3.attention.output.dense.weight')
# 参数的值：(Parameter containing:
# tensor([[-0.0357,  0.0080, -0.0302,  ...,  0.0147,  0.0337, -0.0034],
#         [ 0.0082, -0.0261, -0.0325,  ..., -0.0349,  0.0542,  0.0138],
#         [ 0.0216, -0.0011, -0.0011,  ..., -0.0397, -0.0022,  0.0370],
#         ...,
#         [-0.0375, -0.0355, -0.0160,  ...,  0.0145, -0.0282, -0.0016],
#         [-0.0321,  0.0211, -0.0175,  ..., -0.0313, -0.0060,  0.0085],
#         [ 0.0077,  0.0052,  0.0093,  ..., -0.0047,  0.0400, -0.0491]],
#        requires_grad=True), Parameter containing:
# tensor([[-0.0357,  0.0080, -0.0302,  ...,  0.0147,  0.0337, -0.0034],
#         [ 0.0082, -0.0261, -0.0325,  ..., -0.0349,  0.0542,  0.0138],
#         [ 0.0216, -0.0011, -0.0011,  ..., -0.0397, -0.0022,  0.0370],
#         ...,
#         [-0.0375, -0.0355, -0.0160,  ...,  0.0145, -0.0282, -0.0016],
#         [-0.0321,  0.0211, -0.0175,  ..., -0.0313, -0.0060,  0.0085],
#         [ 0.0077,  0.0052,  0.0093,  ..., -0.0047,  0.0400, -0.0491]],
#        requires_grad=True))
# 参数的值一致
# 模型名称：('encoder.layer.3.attention.output.dense.bias', 'encoder.layer.3.attention.output.dense.bias')
# 参数的值：(Parameter containing:
# tensor([ 0.0253, -0.0007, -0.0324,  ...,  0.0649,  0.0142,  0.0117],
#        requires_grad=True), Parameter containing:
# tensor([ 0.0253, -0.0007, -0.0324,  ...,  0.0649,  0.0142,  0.0117],
#        requires_grad=True))
# 参数的值一致
# 模型名称：('encoder.layer.3.attention.output.LayerNorm.weight', 'encoder.layer.3.attention.output.LayerNorm.weight')
# 参数的值：(Parameter containing:
# tensor([0.9443, 0.8960, 0.9165,  ..., 0.9082, 0.9624, 0.9209],
#        requires_grad=True), Parameter containing:
# tensor([0.9443, 0.8960, 0.9165,  ..., 0.9082, 0.9624, 0.9209],
#        requires_grad=True))
# 参数的值一致
# 模型名称：('encoder.layer.3.attention.output.LayerNorm.bias', 'encoder.layer.3.attention.output.LayerNorm.bias')
# 参数的值：(Parameter containing:
# tensor([0.2159, 0.1875, 0.2542,  ..., 0.2693, 0.2437, 0.2524],
#        requires_grad=True), Parameter containing:
# tensor([0.2159, 0.1875, 0.2542,  ..., 0.2693, 0.2437, 0.2524],
#        requires_grad=True))
# 参数的值一致
# 模型名称：('encoder.layer.3.intermediate.dense.weight', 'encoder.layer.3.intermediate.dense.weight')
# 参数的值：(Parameter containing:
# tensor([[-0.0181,  0.0586, -0.0558,  ..., -0.0616,  0.0130, -0.0229],
#         [ 0.0489, -0.1088,  0.0345,  ...,  0.0512, -0.0391,  0.0035],
#         [-0.0586,  0.0146,  0.0173,  ...,  0.0226,  0.1079, -0.0702],
#         ...,
#         [-0.0560,  0.0104, -0.0790,  ..., -0.0451, -0.0967, -0.0319],
#         [ 0.0355,  0.0417, -0.0102,  ..., -0.0567,  0.0484, -0.1570],
#         [-0.0774, -0.0836, -0.1177,  ..., -0.0087,  0.0135, -0.0118]],
#        requires_grad=True), Parameter containing:
# tensor([[-0.0181,  0.0586, -0.0558,  ..., -0.0616,  0.0130, -0.0229],
#         [ 0.0489, -0.1088,  0.0345,  ...,  0.0512, -0.0391,  0.0035],
#         [-0.0586,  0.0146,  0.0173,  ...,  0.0226,  0.1079, -0.0702],
#         ...,
#         [-0.0560,  0.0104, -0.0790,  ..., -0.0451, -0.0967, -0.0319],
#         [ 0.0355,  0.0417, -0.0102,  ..., -0.0567,  0.0484, -0.1570],
#         [-0.0774, -0.0836, -0.1177,  ..., -0.0087,  0.0135, -0.0118]],
#        requires_grad=True))
# 参数的值一致
# 模型名称：('encoder.layer.3.intermediate.dense.bias', 'encoder.layer.3.intermediate.dense.bias')
# 参数的值：(Parameter containing:
# tensor([-0.0412, -0.0642, -0.0571,  ..., -0.0548, -0.0497, -0.0541],
#        requires_grad=True), Parameter containing:
# tensor([-0.0412, -0.0642, -0.0571,  ..., -0.0548, -0.0497, -0.0541],
#        requires_grad=True))
# 参数的值一致
# 模型名称：('encoder.layer.3.output.dense.weight', 'encoder.layer.3.output.dense.weight')
# 参数的值：(Parameter containing:
# tensor([[-0.0023,  0.0734, -0.0109,  ..., -0.0482,  0.0277,  0.0481],
#         [ 0.0477,  0.0337, -0.0271,  ..., -0.0690,  0.0026, -0.0170],
#         [ 0.0282,  0.0103,  0.0524,  ...,  0.0566,  0.0424,  0.0029],
#         ...,
#         [-0.0351, -0.0435, -0.0265,  ...,  0.0289, -0.1013, -0.0370],
#         [-0.0291, -0.0649, -0.0172,  ...,  0.0214, -0.0096,  0.0746],
#         [ 0.0556,  0.0872, -0.0676,  ...,  0.0027,  0.0037, -0.0475]],
#        requires_grad=True), Parameter containing:
# tensor([[-0.0023,  0.0734, -0.0109,  ..., -0.0482,  0.0277,  0.0481],
#         [ 0.0477,  0.0337, -0.0271,  ..., -0.0690,  0.0026, -0.0170],
#         [ 0.0282,  0.0103,  0.0524,  ...,  0.0566,  0.0424,  0.0029],
#         ...,
#         [-0.0351, -0.0435, -0.0265,  ...,  0.0289, -0.1013, -0.0370],
#         [-0.0291, -0.0649, -0.0172,  ...,  0.0214, -0.0096,  0.0746],
#         [ 0.0556,  0.0872, -0.0676,  ...,  0.0027,  0.0037, -0.0475]],
#        requires_grad=True))
# 参数的值一致
# 模型名称：('encoder.layer.3.output.dense.bias', 'encoder.layer.3.output.dense.bias')
# 参数的值：(Parameter containing:
# tensor([ 0.0278, -0.0170,  0.0019,  ..., -0.0248, -0.0735, -0.0479],
#        requires_grad=True), Parameter containing:
# tensor([ 0.0278, -0.0170,  0.0019,  ..., -0.0248, -0.0735, -0.0479],
#        requires_grad=True))
# 参数的值一致
# 模型名称：('encoder.layer.3.output.LayerNorm.weight', 'encoder.layer.3.output.LayerNorm.weight')
# 参数的值：(Parameter containing:
# tensor([0.9453, 0.8975, 0.9160,  ..., 0.9111, 0.9580, 0.9067],
#        requires_grad=True), Parameter containing:
# tensor([0.9453, 0.8975, 0.9160,  ..., 0.9111, 0.9580, 0.9067],
#        requires_grad=True))
# 参数的值一致
# 模型名称：('encoder.layer.3.output.LayerNorm.bias', 'encoder.layer.3.output.LayerNorm.bias')
# 参数的值：(Parameter containing:
# tensor([-0.0024,  0.0250, -0.0294,  ..., -0.0822, -0.0556, -0.0692],
#        requires_grad=True), Parameter containing:
# tensor([-0.0024,  0.0250, -0.0294,  ..., -0.0822, -0.0556, -0.0692],
#        requires_grad=True))
# 参数的值一致
# 模型名称：('encoder.layer.4.attention.self.query.weight', 'encoder.layer.4.attention.self.query.weight')
# 参数的值：(Parameter containing:
# tensor([[ 0.0707, -0.0389,  0.0953,  ..., -0.0308, -0.0132, -0.0609],
#         [ 0.0298,  0.0385, -0.0787,  ..., -0.0235, -0.0090, -0.0259],
#         [-0.0255,  0.0645,  0.0229,  ..., -0.0145,  0.0582,  0.1893],
#         ...,
#         [ 0.0372, -0.0606, -0.0369,  ..., -0.0150, -0.0865, -0.0404],
#         [ 0.0180,  0.0182,  0.1027,  ...,  0.0969,  0.0620,  0.0048],
#         [-0.0477, -0.0200, -0.0754,  ...,  0.0245,  0.0248,  0.0251]],
#        requires_grad=True), Parameter containing:
# tensor([[ 0.0707, -0.0389,  0.0953,  ..., -0.0308, -0.0132, -0.0609],
#         [ 0.0298,  0.0385, -0.0787,  ..., -0.0235, -0.0090, -0.0259],
#         [-0.0255,  0.0645,  0.0229,  ..., -0.0145,  0.0582,  0.1893],
#         ...,
#         [ 0.0372, -0.0606, -0.0369,  ..., -0.0150, -0.0865, -0.0404],
#         [ 0.0180,  0.0182,  0.1027,  ...,  0.0969,  0.0620,  0.0048],
#         [-0.0477, -0.0200, -0.0754,  ...,  0.0245,  0.0248,  0.0251]],
#        requires_grad=True))
# 参数的值一致
# 模型名称：('encoder.layer.4.attention.self.query.bias', 'encoder.layer.4.attention.self.query.bias')
# 参数的值：(Parameter containing:
# tensor([-0.0825,  0.0839,  0.2617,  ...,  0.0025,  0.3040, -0.0925],
#        requires_grad=True), Parameter containing:
# tensor([-0.0825,  0.0839,  0.2617,  ...,  0.0025,  0.3040, -0.0925],
#        requires_grad=True))
# 参数的值一致
# 模型名称：('encoder.layer.4.attention.self.key.weight', 'encoder.layer.4.attention.self.key.weight')
# 参数的值：(Parameter containing:
# tensor([[-0.0283,  0.0607, -0.0656,  ...,  0.0186,  0.0255,  0.0432],
#         [ 0.0170, -0.0326, -0.0553,  ..., -0.0006, -0.0477,  0.0703],
#         [ 0.0240, -0.0525,  0.0637,  ..., -0.0526, -0.0011,  0.0150],
#         ...,
#         [-0.1144,  0.0170,  0.0968,  ...,  0.0152,  0.0196,  0.0529],
#         [ 0.0069,  0.0091, -0.0195,  ..., -0.0248, -0.0664, -0.0795],
#         [-0.0229, -0.0144, -0.0348,  ..., -0.0044, -0.0386,  0.0359]],
#        requires_grad=True), Parameter containing:
# tensor([[-0.0283,  0.0607, -0.0656,  ...,  0.0186,  0.0255,  0.0432],
#         [ 0.0170, -0.0326, -0.0553,  ..., -0.0006, -0.0477,  0.0703],
#         [ 0.0240, -0.0525,  0.0637,  ..., -0.0526, -0.0011,  0.0150],
#         ...,
#         [-0.1144,  0.0170,  0.0968,  ...,  0.0152,  0.0196,  0.0529],
#         [ 0.0069,  0.0091, -0.0195,  ..., -0.0248, -0.0664, -0.0795],
#         [-0.0229, -0.0144, -0.0348,  ..., -0.0044, -0.0386,  0.0359]],
#        requires_grad=True))
# 参数的值一致
# 模型名称：('encoder.layer.4.attention.self.key.bias', 'encoder.layer.4.attention.self.key.bias')
# 参数的值：(Parameter containing:
# tensor([-0.0190, -0.1070, -0.1467,  ...,  0.1561, -0.2874, -0.1559],
#        requires_grad=True), Parameter containing:
# tensor([-0.0190, -0.1070, -0.1467,  ...,  0.1561, -0.2874, -0.1559],
#        requires_grad=True))
# 参数的值一致
# 模型名称：('encoder.layer.4.attention.self.value.weight', 'encoder.layer.4.attention.self.value.weight')
# 参数的值：(Parameter containing:
# tensor([[-0.0252, -0.0208, -0.0219,  ...,  0.0411, -0.0085, -0.0578],
#         [-0.0039,  0.0200, -0.0231,  ...,  0.0366,  0.0073, -0.0093],
#         [-0.0605,  0.0061, -0.0383,  ..., -0.0367,  0.0105,  0.0075],
#         ...,
#         [-0.0025, -0.0482,  0.0248,  ...,  0.0040, -0.0272, -0.0162],
#         [-0.0093, -0.0084, -0.0376,  ..., -0.0512,  0.0007,  0.0449],
#         [-0.0097, -0.0248, -0.0282,  ..., -0.0022,  0.0186,  0.0115]],
#        requires_grad=True), Parameter containing:
# tensor([[-0.0252, -0.0208, -0.0219,  ...,  0.0411, -0.0085, -0.0578],
#         [-0.0039,  0.0200, -0.0231,  ...,  0.0366,  0.0073, -0.0093],
#         [-0.0605,  0.0061, -0.0383,  ..., -0.0367,  0.0105,  0.0075],
#         ...,
# ...
#         [-0.0029, -0.0278, -0.0379,  ...,  0.0167,  0.0327, -0.0007],
#         [ 0.0409,  0.0552, -0.0233,  ..., -0.0147,  0.0454,  0.0459]],
#        requires_grad=True))
# 参数的值一致
# 模型名称：('encoder.layer.22.attention.output.dense.bias', 'encoder.layer.22.attention.output.dense.bias')
# 参数的值：(Parameter containing:
# tensor([ 0.0343, -0.0659,  0.0149,  ..., -0.1318,  0.0150, -0.0412],
#        requires_grad=True), Parameter containing:
# tensor([ 0.0343, -0.0659,  0.0149,  ..., -0.1318,  0.0150, -0.0412],
#        requires_grad=True))
# 参数的值一致
# 模型名称：('encoder.layer.22.attention.output.LayerNorm.weight', 'encoder.layer.22.attention.output.LayerNorm.weight')
# 参数的值：(Parameter containing:
# tensor([0.9258, 0.9043, 0.8853,  ..., 0.8921, 0.9180, 0.9092],
#        requires_grad=True), Parameter containing:
# tensor([0.9258, 0.9043, 0.8853,  ..., 0.8921, 0.9180, 0.9092],
#        requires_grad=True))
# 参数的值一致
# 模型名称：('encoder.layer.22.attention.output.LayerNorm.bias', 'encoder.layer.22.attention.output.LayerNorm.bias')
# 参数的值：(Parameter containing:
# tensor([-0.0711, -0.0213, -0.0786,  ..., -0.0479, -0.0692, -0.0401],
#        requires_grad=True), Parameter containing:
# tensor([-0.0711, -0.0213, -0.0786,  ..., -0.0479, -0.0692, -0.0401],
#        requires_grad=True))
# 参数的值一致
# 模型名称：('encoder.layer.22.intermediate.dense.weight', 'encoder.layer.22.intermediate.dense.weight')
# 参数的值：(Parameter containing:
# tensor([[ 0.0506, -0.0035,  0.0536,  ...,  0.0359, -0.0276, -0.0011],
#         [ 0.0146, -0.0116,  0.0051,  ..., -0.0062, -0.0176,  0.0210],
#         [ 0.0320, -0.0187, -0.0165,  ...,  0.0100,  0.0044,  0.0239],
#         ...,
#         [-0.0105, -0.0489,  0.0351,  ...,  0.0460, -0.0115,  0.0161],
#         [ 0.0310, -0.0002,  0.0311,  ..., -0.0089, -0.0056,  0.0217],
#         [ 0.0044,  0.0142,  0.0361,  ..., -0.0108, -0.0487,  0.0129]],
#        requires_grad=True), Parameter containing:
# tensor([[ 0.0506, -0.0035,  0.0536,  ...,  0.0359, -0.0276, -0.0011],
#         [ 0.0146, -0.0116,  0.0051,  ..., -0.0062, -0.0176,  0.0210],
#         [ 0.0320, -0.0187, -0.0165,  ...,  0.0100,  0.0044,  0.0239],
#         ...,
#         [-0.0105, -0.0489,  0.0351,  ...,  0.0460, -0.0115,  0.0161],
#         [ 0.0310, -0.0002,  0.0311,  ..., -0.0089, -0.0056,  0.0217],
#         [ 0.0044,  0.0142,  0.0361,  ..., -0.0108, -0.0487,  0.0129]],
#        requires_grad=True))
# 参数的值一致
# 模型名称：('encoder.layer.22.intermediate.dense.bias', 'encoder.layer.22.intermediate.dense.bias')
# 参数的值：(Parameter containing:
# tensor([-0.0790, -0.0770, -0.0961,  ...,  0.0184, -0.0060, -0.0597],
#        requires_grad=True), Parameter containing:
# tensor([-0.0790, -0.0770, -0.0961,  ...,  0.0184, -0.0060, -0.0597],
#        requires_grad=True))
# 参数的值一致
# 模型名称：('encoder.layer.22.output.dense.weight', 'encoder.layer.22.output.dense.weight')
# 参数的值：(Parameter containing:
# tensor([[ 0.0681,  0.0031, -0.0147,  ..., -0.0542, -0.0063,  0.0153],
#         [ 0.0234,  0.0159,  0.0348,  ...,  0.0087, -0.0092, -0.0164],
#         [ 0.0667,  0.0343,  0.0492,  ..., -0.0521, -0.0619, -0.0554],
#         ...,
#         [ 0.0564, -0.0222,  0.0161,  ..., -0.1287, -0.1229, -0.0143],
#         [ 0.0271,  0.0065,  0.0251,  ..., -0.0133, -0.0012,  0.0228],
#         [-0.0117,  0.0441, -0.0101,  ...,  0.0097, -0.0063, -0.0013]],
#        requires_grad=True), Parameter containing:
# tensor([[ 0.0681,  0.0031, -0.0147,  ..., -0.0542, -0.0063,  0.0153],
#         [ 0.0234,  0.0159,  0.0348,  ...,  0.0087, -0.0092, -0.0164],
#         [ 0.0667,  0.0343,  0.0492,  ..., -0.0521, -0.0619, -0.0554],
#         ...,
#         [ 0.0564, -0.0222,  0.0161,  ..., -0.1287, -0.1229, -0.0143],
#         [ 0.0271,  0.0065,  0.0251,  ..., -0.0133, -0.0012,  0.0228],
#         [-0.0117,  0.0441, -0.0101,  ...,  0.0097, -0.0063, -0.0013]],
#        requires_grad=True))
# 参数的值一致
# 模型名称：('encoder.layer.22.output.dense.bias', 'encoder.layer.22.output.dense.bias')
# 参数的值：(Parameter containing:
# tensor([ 0.0084, -0.0016, -0.0269,  ..., -0.0526, -0.0025,  0.0182],
#        requires_grad=True), Parameter containing:
# tensor([ 0.0084, -0.0016, -0.0269,  ..., -0.0526, -0.0025,  0.0182],
#        requires_grad=True))
# 参数的值一致
# 模型名称：('encoder.layer.22.output.LayerNorm.weight', 'encoder.layer.22.output.LayerNorm.weight')
# 参数的值：(Parameter containing:
# tensor([0.9077, 0.8618, 0.8555,  ..., 0.8574, 0.9175, 0.9043],
#        requires_grad=True), Parameter containing:
# tensor([0.9077, 0.8618, 0.8555,  ..., 0.8574, 0.9175, 0.9043],
#        requires_grad=True))
# 参数的值一致
# 模型名称：('encoder.layer.22.output.LayerNorm.bias', 'encoder.layer.22.output.LayerNorm.bias')
# 参数的值：(Parameter containing:
# tensor([ 0.0210,  0.0044, -0.0119,  ...,  0.0229, -0.0042,  0.0004],
#        requires_grad=True), Parameter containing:
# tensor([ 0.0210,  0.0044, -0.0119,  ...,  0.0229, -0.0042,  0.0004],
#        requires_grad=True))
# 参数的值一致
# 模型名称：('encoder.layer.23.attention.self.query.weight', 'encoder.layer.23.attention.self.query.weight')
# 参数的值：(Parameter containing:
# tensor([[-0.0540,  0.0967,  0.0216,  ..., -0.0076, -0.0950,  0.0726],
#         [ 0.0629, -0.0485, -0.0234,  ...,  0.0246, -0.0152,  0.0350],
#         [ 0.0026,  0.0489,  0.0065,  ..., -0.0262, -0.0715, -0.0470],
#         ...,
#         [-0.0434,  0.0420,  0.0286,  ..., -0.0257,  0.0755,  0.0032],
#         [ 0.0253,  0.0479,  0.0508,  ...,  0.0193,  0.0002,  0.0211],
#         [-0.0092, -0.0291, -0.0173,  ...,  0.0239,  0.0139, -0.0395]],
#        requires_grad=True), Parameter containing:
# tensor([[-0.0540,  0.0967,  0.0216,  ..., -0.0076, -0.0950,  0.0726],
#         [ 0.0629, -0.0485, -0.0234,  ...,  0.0246, -0.0152,  0.0350],
#         [ 0.0026,  0.0489,  0.0065,  ..., -0.0262, -0.0715, -0.0470],
#         ...,
#         [-0.0434,  0.0420,  0.0286,  ..., -0.0257,  0.0755,  0.0032],
#         [ 0.0253,  0.0479,  0.0508,  ...,  0.0193,  0.0002,  0.0211],
#         [-0.0092, -0.0291, -0.0173,  ...,  0.0239,  0.0139, -0.0395]],
#        requires_grad=True))
# 参数的值一致
# 模型名称：('encoder.layer.23.attention.self.query.bias', 'encoder.layer.23.attention.self.query.bias')
# 参数的值：(Parameter containing:
# tensor([-0.0604,  0.0616,  0.0291,  ...,  0.0320,  0.0125, -0.0370],
#        requires_grad=True), Parameter containing:
# tensor([-0.0604,  0.0616,  0.0291,  ...,  0.0320,  0.0125, -0.0370],
#        requires_grad=True))
# 参数的值一致
# 模型名称：('encoder.layer.23.attention.self.key.weight', 'encoder.layer.23.attention.self.key.weight')
# 参数的值：(Parameter containing:
# tensor([[-0.0025, -0.0075,  0.0423,  ...,  0.0348,  0.0021, -0.0446],
#         [ 0.0365, -0.0242, -0.0745,  ..., -0.0433,  0.0054, -0.0413],
#         [ 0.0139,  0.0480, -0.0529,  ..., -0.0646,  0.0229, -0.0363],
#         ...,
#         [ 0.0750, -0.0128, -0.0663,  ..., -0.0189,  0.0292, -0.0066],
#         [ 0.0190,  0.0018, -0.0465,  ..., -0.0028,  0.0111, -0.0018],
#         [-0.0056,  0.0138,  0.0240,  ...,  0.0013, -0.0570,  0.0427]],
#        requires_grad=True), Parameter containing:
# tensor([[-0.0025, -0.0075,  0.0423,  ...,  0.0348,  0.0021, -0.0446],
#         [ 0.0365, -0.0242, -0.0745,  ..., -0.0433,  0.0054, -0.0413],
#         [ 0.0139,  0.0480, -0.0529,  ..., -0.0646,  0.0229, -0.0363],
#         ...,
#         [ 0.0750, -0.0128, -0.0663,  ..., -0.0189,  0.0292, -0.0066],
#         [ 0.0190,  0.0018, -0.0465,  ..., -0.0028,  0.0111, -0.0018],
#         [-0.0056,  0.0138,  0.0240,  ...,  0.0013, -0.0570,  0.0427]],
#        requires_grad=True))
# 参数的值一致
# 模型名称：('encoder.layer.23.attention.self.key.bias', 'encoder.layer.23.attention.self.key.bias')
# 参数的值：(Parameter containing:
# tensor([-0.2983,  0.1877,  0.3320,  ...,  0.0634,  0.2693, -0.1910],
#        requires_grad=True), Parameter containing:
# tensor([-0.2983,  0.1877,  0.3320,  ...,  0.0634,  0.2693, -0.1910],
#        requires_grad=True))
# 参数的值一致
# 模型名称：('encoder.layer.23.attention.self.value.weight', 'encoder.layer.23.attention.self.value.weight')
# 参数的值：(Parameter containing:
# tensor([[ 0.0077,  0.0212, -0.0064,  ..., -0.0354, -0.0488, -0.0429],
#         [-0.0381,  0.0078,  0.0331,  ...,  0.0050, -0.0013, -0.0183],
#         [ 0.0243,  0.0735, -0.0412,  ..., -0.0277, -0.0693,  0.0245],
#         ...,
#         [ 0.0235, -0.0278, -0.0082,  ...,  0.0068, -0.0321,  0.0146],
#         [-0.0685, -0.0146, -0.0370,  ...,  0.0415,  0.0205, -0.0496],
#         [ 0.0076,  0.0403,  0.0089,  ...,  0.0209, -0.0164,  0.0293]],
#        requires_grad=True), Parameter containing:
# tensor([[ 0.0077,  0.0212, -0.0064,  ..., -0.0354, -0.0488, -0.0429],
#         [-0.0381,  0.0078,  0.0331,  ...,  0.0050, -0.0013, -0.0183],
#         [ 0.0243,  0.0735, -0.0412,  ..., -0.0277, -0.0693,  0.0245],
#         ...,
#         [ 0.0235, -0.0278, -0.0082,  ...,  0.0068, -0.0321,  0.0146],
#         [-0.0685, -0.0146, -0.0370,  ...,  0.0415,  0.0205, -0.0496],
#         [ 0.0076,  0.0403,  0.0089,  ...,  0.0209, -0.0164,  0.0293]],
#        requires_grad=True))
# 参数的值一致
# 模型名称：('encoder.layer.23.attention.self.value.bias', 'encoder.layer.23.attention.self.value.bias')
# 参数的值：(Parameter containing:
# tensor([-0.0107, -0.0016,  0.0199,  ...,  0.0140, -0.0155,  0.0038],
#        requires_grad=True), Parameter containing:
# tensor([-0.0107, -0.0016,  0.0199,  ...,  0.0140, -0.0155,  0.0038],
#        requires_grad=True))
# 参数的值一致
# 模型名称：('encoder.layer.23.attention.output.dense.weight', 'encoder.layer.23.attention.output.dense.weight')
# 参数的值：(Parameter containing:
# tensor([[-0.0178, -0.0293,  0.0293,  ...,  0.0110, -0.0255,  0.0161],
#         [ 0.0303,  0.0302,  0.0373,  ..., -0.0027, -0.0351,  0.0436],
#         [-0.0497, -0.0222,  0.0041,  ..., -0.0180, -0.0230,  0.0321],
#         ...,
#         [-0.0079,  0.0075, -0.0446,  ...,  0.0173,  0.0528,  0.0359],
#         [-0.0300, -0.0094, -0.0146,  ..., -0.0332, -0.0311, -0.0025],
#         [-0.0245, -0.0130,  0.0029,  ..., -0.0239, -0.0099, -0.0198]],
#        requires_grad=True), Parameter containing:
# tensor([[-0.0149, -0.0202,  0.0250,  ...,  0.0104, -0.0300,  0.0247],
#         [ 0.0220,  0.0244,  0.0346,  ...,  0.0017, -0.0286,  0.0485],
#         [-0.0475, -0.0202, -0.0005,  ..., -0.0130, -0.0250,  0.0329],
#         ...,
#         [-0.0038,  0.0031, -0.0512,  ...,  0.0224,  0.0538,  0.0352],
#         [-0.0317, -0.0073, -0.0172,  ..., -0.0368, -0.0309,  0.0005],
#         [-0.0221, -0.0103,  0.0071,  ..., -0.0245, -0.0176, -0.0311]],
#        requires_grad=True))
# 参数的值不同
# 模型名称：('encoder.layer.23.attention.output.dense.bias', 'encoder.layer.23.attention.output.dense.bias')
# 参数的值：(Parameter containing:
# tensor([-0.0381, -0.0553,  0.0157,  ..., -0.0384,  0.0095,  0.0108],
#        requires_grad=True), Parameter containing:
# tensor([-0.0345, -0.0597,  0.0204,  ..., -0.0356,  0.0132,  0.0093],
#        requires_grad=True))
# 参数的值不同
# 模型名称：('encoder.layer.23.attention.output.LayerNorm.weight', 'encoder.layer.23.attention.output.LayerNorm.weight')
# 参数的值：(Parameter containing:
# tensor([0.8955, 0.9043, 0.8721,  ..., 0.9082, 0.8984, 0.9229],
#        requires_grad=True), Parameter containing:
# tensor([0.8950, 0.9105, 0.8731,  ..., 0.9172, 0.9053, 0.9228],
#        requires_grad=True))
# 参数的值不同
# 模型名称：('encoder.layer.23.attention.output.LayerNorm.bias', 'encoder.layer.23.attention.output.LayerNorm.bias')
# 参数的值：(Parameter containing:
# tensor([ 0.0237,  0.0212, -0.1807,  ...,  0.0916, -0.1613,  0.0739],
#        requires_grad=True), Parameter containing:
# tensor([ 0.0370,  0.0192, -0.1692,  ...,  0.0993, -0.1516,  0.0736],
#        requires_grad=True))
# 参数的值不同
# 模型名称：('encoder.layer.23.intermediate.dense.weight', 'encoder.layer.23.intermediate.dense.weight')
# 参数的值：(Parameter containing:
# tensor([[ 0.0542,  0.0086,  0.0023,  ..., -0.0324, -0.0090,  0.0261],
#         [-0.0221,  0.0541,  0.0177,  ..., -0.0383,  0.0173,  0.0211],
#         [ 0.0370, -0.0108, -0.0017,  ..., -0.0019, -0.0508,  0.0002],
#         ...,
#         [-0.0201,  0.0163,  0.0304,  ..., -0.0102, -0.0036,  0.0318],
#         [ 0.0682, -0.0029,  0.0321,  ..., -0.0202,  0.0344, -0.0522],
#         [-0.0058,  0.0122, -0.0070,  ...,  0.0158,  0.0366, -0.0727]],
#        requires_grad=True), Parameter containing:
# tensor([[ 0.0514,  0.0110,  0.0002,  ..., -0.0338, -0.0112,  0.0245],
#         [-0.0204,  0.0547,  0.0140,  ..., -0.0369,  0.0133,  0.0233],
#         [ 0.0345, -0.0071, -0.0001,  ...,  0.0009, -0.0517,  0.0030],
#         ...,
#         [-0.0179,  0.0186,  0.0314,  ..., -0.0084, -0.0095,  0.0279],
#         [ 0.0682, -0.0077,  0.0290,  ..., -0.0180,  0.0348, -0.0517],
#         [-0.0109,  0.0116, -0.0106,  ...,  0.0143,  0.0393, -0.0723]],
#        requires_grad=True))
# 参数的值不同
# 模型名称：('encoder.layer.23.intermediate.dense.bias', 'encoder.layer.23.intermediate.dense.bias')
# 参数的值：(Parameter containing:
# tensor([-0.0421, -0.0553, -0.0421,  ..., -0.0375, -0.0285, -0.0294],
#        requires_grad=True), Parameter containing:
# tensor([-0.0380, -0.0542, -0.0388,  ..., -0.0335, -0.0325, -0.0280],
#        requires_grad=True))
# 参数的值不同
# 模型名称：('encoder.layer.23.output.dense.weight', 'encoder.layer.23.output.dense.weight')
# 参数的值：(Parameter containing:
# tensor([[-0.0141, -0.0009,  0.0037,  ...,  0.0199,  0.0209, -0.0160],
#         [-0.0806,  0.0406, -0.0575,  ...,  0.0189,  0.0166, -0.0637],
#         [ 0.0691,  0.0247,  0.0247,  ..., -0.0768,  0.0467, -0.0362],
#         ...,
#         [-0.0289,  0.0294,  0.0136,  ..., -0.0578, -0.0449, -0.0563],
#         [ 0.0264,  0.0103,  0.0616,  ..., -0.0212,  0.0268, -0.0034],
#         [-0.0027, -0.0228,  0.0135,  ..., -0.0013,  0.0039,  0.0120]],
#        requires_grad=True), Parameter containing:
# tensor([[-0.0204, -0.0014, -0.0089,  ...,  0.0245,  0.0176, -0.0106],
#         [-0.0768,  0.0367, -0.0543,  ...,  0.0175,  0.0152, -0.0662],
#         [ 0.0633,  0.0143,  0.0174,  ..., -0.0808,  0.0463, -0.0378],
#         ...,
#         [-0.0289,  0.0271,  0.0064,  ..., -0.0545, -0.0478, -0.0616],
#         [ 0.0234,  0.0115,  0.0531,  ..., -0.0208,  0.0209, -0.0041],
#         [ 0.0024, -0.0218,  0.0106,  ...,  0.0031,  0.0028,  0.0184]],
#        requires_grad=True))
# 参数的值不同
# 模型名称：('encoder.layer.23.output.dense.bias', 'encoder.layer.23.output.dense.bias')
# 参数的值：(Parameter containing:
# tensor([-0.0150, -0.0401,  0.0353,  ..., -0.0072,  0.0311, -0.0255],
#        requires_grad=True), Parameter containing:
# tensor([-0.0102, -0.0429,  0.0365,  ..., -0.0068,  0.0348, -0.0273],
#        requires_grad=True))
# 参数的值不同
# 模型名称：('encoder.layer.23.output.LayerNorm.weight', 'encoder.layer.23.output.LayerNorm.weight')
# 参数的值：(Parameter containing:
# tensor([0.9595, 0.9268, 0.8828,  ..., 0.9429, 0.9395, 0.9463],
#        requires_grad=True), Parameter containing:
# tensor([0.9583, 0.9341, 0.8861,  ..., 0.9513, 0.9459, 0.9441],
#        requires_grad=True))
# 参数的值不同
# 模型名称：('encoder.layer.23.output.LayerNorm.bias', 'encoder.layer.23.output.LayerNorm.bias')
# 参数的值：(Parameter containing:
# tensor([-0.0001, -0.0137, -0.0276,  ..., -0.0299, -0.0319, -0.0323],
#        requires_grad=True), Parameter containing:
# tensor([ 0.0109, -0.0190, -0.0211,  ..., -0.0231, -0.0217, -0.0358],
#        requires_grad=True))
# 参数的值不同
# 模型名称：('pooler.dense.weight', 'pooler.dense.weight')
# 参数的值：(Parameter containing:
# tensor([[-0.0202, -0.0158, -0.0057,  ..., -0.0154, -0.0061,  0.0168],
#         [ 0.0623,  0.0209, -0.0149,  ...,  0.0143,  0.0045, -0.0160],
#         [-0.0006,  0.0024, -0.0091,  ...,  0.0254,  0.0005, -0.0318],
#         ...,
#         [ 0.0178,  0.0062, -0.0266,  ...,  0.0311,  0.0212, -0.0380],
#         [ 0.0031, -0.0038, -0.0266,  ..., -0.0169,  0.0171,  0.0103],
#         [-0.0143,  0.0225, -0.0005,  ..., -0.0049, -0.0049, -0.0214]],
#        requires_grad=True), Parameter containing:
# tensor([[-0.0202, -0.0158, -0.0057,  ..., -0.0154, -0.0061,  0.0168],
#         [ 0.0623,  0.0209, -0.0149,  ...,  0.0143,  0.0045, -0.0160],
#         [-0.0006,  0.0024, -0.0091,  ...,  0.0254,  0.0005, -0.0318],
#         ...,
#         [ 0.0178,  0.0062, -0.0266,  ...,  0.0311,  0.0212, -0.0380],
#         [ 0.0031, -0.0038, -0.0266,  ..., -0.0169,  0.0171,  0.0103],
#         [-0.0143,  0.0225, -0.0005,  ..., -0.0049, -0.0049, -0.0214]],
#        requires_grad=True))
# 参数的值一致
# 模型名称：('pooler.dense.bias', 'pooler.dense.bias')
# 参数的值：(Parameter containing:
# tensor([0., 0., 0.,  ..., 0., 0., 0.], requires_grad=True), Parameter containing:
# tensor([0., 0., 0.,  ..., 0., 0., 0.], requires_grad=True))
# 参数的值一致

# %% [markdown]
# ### 02 微调后模型效果的评估

# %% [markdown]
# #### 1、 模型及向量数据库加载

# %%
#### 2、向量数据库加载
path="./model/BGEm3_Law_new/"
model = BGEM3FlagModel(path,pooling_method='cls',use_fp16=False,return_sparse = True,trust_remote_code=True) # Setting use_fp16 to True speeds up computation with a slight performance degradation

# %%
### 2.1、数据加载 + 批量向量化
import pandas as pd
data = pd.read_csv("./law_faq.csv")
data=data.dropna()

# %%
query_list=list(data["title"])
reply=list(data["reply"])
knowledge_embedder=model.encode(reply)

from faiss_index import Faissindex
#  采用暴力检索的方式，即计算查询向量与所有数据库向量之间的距离，然后返回相似度最高的前k个向量。
#  归一化vectors
vectors=knowledge_embedder['dense_vecs']

sl_fassi=Faissindex(1024)
sl_fassi.create(vectors)
# Out:
# pre tokenize: 100%|██████████| 72/72 [00:02<00:00, 27.32it/s]
# You're using a XLMRobertaTokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
# Inference Embeddings: 100%|██████████| 72/72 [01:08<00:00,  1.05it/s]

# %%
### 检索的例子
### 对于i的结果进行测试：
i=1
print(query_list[i])
print(reply[i])

vectors_single_test=np.reshape(model.encode(query_list[i]).get('dense_vecs'), (1, -1))
scores_test,index_test=sl_fassi.search(vectors_single_test,5)

print(index_test)
topk_result = data["reply"].values[index_test[0].tolist()]
topk_result
# Out:
# 盗窃罪的犯罪客体是什么，盗窃罪的犯罪主体
# 盗窃罪的客体要件本罪侵犯的客体是公私财物的所有权。侵犯的对象，是国家、集体或个人的财物，一般是指动产而言，但不动产上之附着物，可与不动产分离的，例如，田地上的农作物，山上的树木、建筑物上之门窗等，也可以成为本罪的对象。另外，能源如电力、煤气也可成为本罪的对象。盗窃罪侵犯的客体是公私财物的所有权。所有权包括占有、使用、收益、处分等权能。这里的所有权一般指合法的所有权，但有时也有例外情况。根据《最高人民法院关于审理盗窃案件具体应用法律若干问题的解释》(以下简称《解释》)的规定：“盗窃违禁品，按盗窃罪处理的，不计数额，根据情节轻重量刑。盗窃违禁品或犯罪分子不法占有的财物也构成盗窃罪。”
# [[    1 10688 10414 10780 12320]]
# array(['盗窃罪的客体要件本罪侵犯的客体是公私财物的所有权。侵犯的对象，是国家、集体或个人的财物，一般是指动产而言，但不动产上之附着物，可与不动产分离的，例如，田地上的农作物，山上的树木、建筑物上之门窗等，也可以成为本罪的对象。另外，能源如电力、煤气也可成为本罪的对象。盗窃罪侵犯的客体是公私财物的所有权。所有权包括占有、使用、收益、处分等权能。这里的所有权一般指合法的所有权，但有时也有例外情况。根据《最高人民法院关于审理盗窃案件具体应用法律若干问题的解释》(以下简称《解释》)的规定：“盗窃违禁品，按盗窃罪处理的，不计数额，根据情节轻重量刑。盗窃违禁品或犯罪分子不法占有的财物也构成盗窃罪。”',
#        '根据刑法第264条的规定，盗窃罪是指以非法占有为目的，窃取公私财物数额较大或者多次盗窃、入户盗窃、携带凶器盗窃、扒窃公私财物的行为。构成要件客体要件本罪侵犯的客体是公私财物的所有权。侵犯的对象，是国家、集体或个人的财物，一般是指动产而言，但不动产上之附着物，可与不动产分离的，例如，田地上的农作物，山上的树木、建筑物上之门窗等，也可以成为本罪的对象。另外，能源如电力、煤气也可成为本罪的对象。盗窃罪侵犯的客体是公私财物的所有权。所有权包括占有、使用、收益、处分等权能。这里的所有权一般指合法的所有权，但有时也有例外情况。根据《最高人民法院关于审理盗窃案件具体应用法律若干问题的解释》（以下简称《解释》的规定：“盗窃违禁品，按盗窃罪处理的，不计数额，根据情节轻重量刑。盗窃违禁品或犯罪分子不法占有的财物也构成盗窃罪。”客观要件本罪在客观方面表现为行为人具有窃取数额较大的公私财物或者多次窃取公私财物、入户盗窃、携带凶器盗窃、扒窃的行为。所谓窃取，是指行为人违反被害人的意志，将他人占有的财物转移为自己或第三者（包括单位）占有。主体要件本罪主体是一般主体，凡达到刑事责任年龄（16周岁）且具备刑事责任能力的人均能构成。对主体的修改是对本罪修改的重要内容。依原刑法，已满14岁不满16岁的少年犯惯窃罪、重大盗窃罪的，应当负刑事责任。本法取消了此规定。主观要件本罪在主观方面表现为直接故意，且具有非法占有的目的。',
#        '根据刑法第264条的规定，盗窃罪是指以非法占有为目的，窃取公私财物数额较大或者多次盗窃、入户盗窃、携带凶器盗窃、扒窃公私财物的行为。构成要件：客体要件本罪侵犯的客体是公私财物的所有权。侵犯的对象，是国家、集体或个人的财物，一般是指动产而言，但不动产上之附着物，可与不动产分离的，例如，田地上的农作物，山上的树木、建筑物上之门窗等，也可以成为本罪的对象。另外，能源如电力、煤气也可成为本罪的对象。盗窃罪侵犯的客体是公私财物的所有权。所有权包括占有、使用、收益、处分等权能。这里的所有权一般指合法的所有权，但有时也有例外情况。根据《最高人民法院关于审理盗窃案件具体应用法律若干问题的解释》（以下简称《解释》的规定：“盗窃违禁品，按盗窃罪处理的，不计数额，根据情节轻重量刑。盗窃违禁品或犯罪分子不法占有的财物也构成盗窃罪。”客观要件本罪在客观方面表现为行为人具有窃取数额较大的公私财物或者多次窃取公私财物、入户盗窃、携带凶器盗窃、扒窃的行为。所谓窃取，是指行为人违反被害人的意志，将他人占有的财物转移为自己或第三者（包括单位）占有。主体要件本罪主体是一般主体，凡达到刑事责任年龄（16周岁）且具备刑事责任能力的人均能构成。对主体的修改是对本罪修改的重要内容。依原刑法，已满14岁不满16岁的少年犯惯窃罪、重大盗窃罪的，应当负刑事责任。本法取消了此规定。主观要件本罪在主观方面表现为直接故意，且具有非法占有的目的。',
#        '一、盗窃罪的构成要件盗窃罪，是指以非法占有为目的，秘密窃取数额较大的公私财物或者多次窃取的行为。盗窃罪的构成要件如下：(一)本罪的客体是公私财产所有权，犯罪对象一般为动产，但不动产的可动部分如房屋的门窗、土地上生长的树木也可以成为盗窃罪的对象。盗窃罪的对象一般是有形的物品，但某些无形的、缺少有体性而有经济价值的东西，如电力、煤气、天然气、重要技术成果也可以成为本罪的对象。(二)本罪的客体方面，一般表现为以秘密窃取的方法，将公私财物转移到*己的控制之下，并非法占有的行为。秘密窃取是指行为*采用*认为不使他*发觉的方法占有他*财物。只要行为*主观上是意图秘密窃取，即使客观上已被他*发觉或者注意，也不影响盗窃性质的认定。秘密窃取，可以是被害*不在场时实施，也可以是物主在场时乘其不备实施。(三)本罪的主体是一般主体，只能由*然*构成。(四)本罪的主观方面是直接故意，即明知是他*或者单位所有或持有的财物，以非法占有为目的，实施窃取财物的行为。误认他*的财物为*己的财物而取走，因不具有非法占有他*财物的目的，不构成盗窃罪。二、单位能否构成盗窃罪关于单位盗窃问题，最******于1996年1月23日针对内*古*治*和江*省*****的请示批复规定：“单位组织实施盗窃，获取财产归单位所有，数额巨大，情节恶劣的，应对其直接负责的主管*员和其他主要的直接责任*员按盗窃罪依法批捕，起诉。”',
#        '根据刑法第264条的规定，盗窃罪是指以非法占有为目的，秘密窃取公私财物数额较大或者多次盗窃、入户盗窃、携带凶器盗窃、扒窃公私财物的行为。盗窃罪侵犯的客体是公私财物的所有权。所有权包括占有、使用、收益、处分等权能。这个肯定是作为的方式，不可能是不作为的方式。'],
#       dtype=object)

# %% [markdown]
# #### 2、计算原模型的前30位的计算错误比例

# %%
### 计算结果：
from tqdm import tqdm
bench_select=[10,20,30]

for bench in  bench_select:
    wrong_index=[]
    
    for i, query_x in tqdm(enumerate(query_list), desc="Processing queries"):
        ## 进行检索：
        vectors_single=model.encode(query_x).get('dense_vecs')
        vectors_single=np.reshape(vectors_single, (1, -1))
        scores, indexes=sl_fassi.search(vectors_single,bench)
        is_corr=0
        for index in indexes[0]:
            if bool(index==i):
                is_corr=is_corr+1
        if is_corr==0:
            wrong_index.append(i)
            
    print(f"Bench为{bench}的情况下，错误比例为：{len(wrong_index)/len(query_list)*100}%")
# Out:
# Processing queries: 18208it [05:17, 57.27it/s]
# Bench为10的情况下，错误比例为：49.90114235500879%
# Processing queries: 18208it [05:11, 58.38it/s]
# Bench为20的情况下，错误比例为：42.04195957820738%
# Processing queries: 18208it [05:10, 58.56it/s]
# Bench为30的情况下，错误比例为：37.59885764499121%
